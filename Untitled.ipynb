# %%
import os
import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageFilter


from utils.jupyter_utils import ImageLinePlotter

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
         print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.float32(np.array(Image.open(seg_file)))

    plotter = ImageLinePlotter(seg_file, plot_area_num=2)
    plotter.add_image(org_img, title='input')
    plotter.add_image(seg_img_PIL, title='mask (load with PIL)')
    plotter.show_plot()
# Out:
# #  benign1.png
# not found org_file :  ./VOC2012/JPEGImages/benign1.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-08e0d1950cac> in <module>
#      17     plotter.add_image(org_img, title='input')
#      18     plotter.add_image(seg_img_PIL, title='mask (load with PIL)')
# ---> 19     plotter.show_plot()
#
# ~/Desktop/all/labo/cancerL_benign2/utils/jupyter_utils.py in show_plot(self)
#      45             plt.title(title)
#      46             hide_ax_frame(ax)
# ---> 47             plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#      48         plt.show()
#
# error: OpenCV(4.3.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
        print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.float32(np.array(Image.open(seg_file)))
    seg_img_cv2 = cv2.imread(seg_file)

    plotter = ImageLinePlotter(seg_file, plot_area_num=3)
    plotter.add_image(org_img, title='input')
    plotter.add_image(seg_img_PIL, title='mask (load with PIL)')
    plotter.add_image(seg_img_cv2, title='mask (load with cv2)')
    plotter.show_plot()

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
        print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.array(Image.open(seg_file))
    seg_img_cv2 = cv2.imread(seg_file)

    print('seg_img_PIL values : ', np.unique(seg_img_PIL))
    print('seg_img_cv2 values : ', np.unique(seg_img_cv2))
# Out:
# #  benign1.png
# not found org_file :  ./VOC2012/JPEGImages/benign1.jpg
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  benign10.png
# not found org_file :  ./VOC2012/JPEGImages/benign10.jpg
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  benign100.png
# not found org_file :  ./VOC2012/JPEGImages/benign100.jpg
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  benign101.png
# not found org_file :  ./VOC2012/JPEGImages/benign101.jpg
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  benign102.png
# not found org_file :  ./VOC2012/JPEGImages/benign102.jpg
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]

# %%
import shutil

TARGET_DIR = os.path.join('.', 'target_data')

ID_CANCER = 1

cls_counters = {}
for seg_file in segs:
    seg_img_PIL = np.array(Image.open(seg_file))

    copy_to = ''
    if np.any(seg_img_PIL == ID_CANCER):
         copy_to += 'cancer_'

    if copy_to == '':
        continue
    if not copy_to in cls_counters.keys():
            cls_counters[copy_to] = 0
    cls_counters[copy_to] += 1

    copy_path = os.path.join(TARGET_DIR, copy_to)
    if not os.path.exists(copy_path):
        os.makedirs(copy_path)
    shutil.copy(seg_file, copy_path)

print(cls_counters)
# Out:
# {'cancer_': 437}

# %%
chk_data = os.path.join('data', 'train', 'inputs','cancer_', 'malignant1.jpg')

img = Image.open(chk_data)

img_arr = np.array(img)
print('original unique : ', np.unique(img_arr))
print('---------------------------------------------------')

pil_resize = img.resize((1000, 1000))
pil_resize_arr = np.array(pil_resize)
print('PIL resized unique : ', np.unique(pil_resize_arr))
print('---------------------------------------------------')

cv2_resize = cv2.resize(img_arr, (1000, 1000))
print('cv2 resized unique : ', np.unique(cv2_resize))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-684bb3d2b61e> in <module>
#       1 chk_data = os.path.join('data', 'train', 'inputs','cancer_', 'malignant1.jpg')
#       2
# ----> 3 img = Image.open(chk_data)
#       4
#       5 img_arr = np.array(img)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train/inputs/cancer_/malignant1.jpg'

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-01-04 18:08:02.427520: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-01-04 18:08:02.438458: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdb4a757110 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-04 18:08:02.438510: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# <keras.engine.training.Model object at 0x16012d630>
# (Dimension(128), Dimension(128))
# <train> Log :  data/train
# <train> Log :  data/train/teachers
# <train> Log :  train_generator.data_size() :  0
# <train> Log :  valid_generator.data_size() :  0
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Traceback (most recent call last):
#   File "train.py", line 63, in <module>
#     callbacks=[tensorboard_callback]
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/engine/training.py", line 1732, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/engine/training_generator.py", line 76, in fit_generator
#     raise ValueError('`validation_steps=None` is only valid for a'
# ValueError: `validation_steps=None` is only valid for a generator based on the `keras.utils.Sequence` class. Please specify `validation_steps` or use the `keras.utils.Sequence` class.

# %% [markdown]
# #推論

# %%
# !python train_with_checkpointcallback.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-01-05 12:52:14.443202: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-01-05 12:52:14.453830: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdfd39a1ae0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 12:52:14.453845: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# <train> Log :  train_generator.data_size() :  349
# <train> Log :  valid_generator.data_size() :  88
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/150
# 6/6 [==============================] - 163s 27s/step - loss: 0.4326 - acc: 0.8438 - val_loss: 0.6932 - val_acc: 0.9471
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/150
# 6/6 [==============================] - 155s 26s/step - loss: 0.2621 - acc: 0.9283 - val_loss: 0.9287 - val_acc: 0.9371
# Epoch 3/150
# 6/6 [==============================] - 156s 26s/step - loss: 0.2417 - acc: 0.9334 - val_loss: 0.6880 - val_acc: 0.9468
# Epoch 4/150
# 6/6 [==============================] - 159s 26s/step - loss: 0.2441 - acc: 0.9294 - val_loss: 0.9440 - val_acc: 0.9427
# Epoch 5/150
# 6/6 [==============================] - 159s 26s/step - loss: 0.2237 - acc: 0.9323 - val_loss: 0.6932 - val_acc: 0.9409
#
# Epoch 00005: val_loss improved from inf to 0.69315, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 6/150
# 6/6 [==============================] - 158s 26s/step - loss: 0.2246 - acc: 0.9272 - val_loss: 0.6874 - val_acc: 0.9459
# Epoch 7/150
# 6/6 [==============================] - 159s 27s/step - loss: 0.2102 - acc: 0.9278 - val_loss: 0.6919 - val_acc: 0.9453
# Epoch 8/150
# 6/6 [==============================] - 161s 27s/step - loss: 0.1926 - acc: 0.9335 - val_loss: 0.6917 - val_acc: 0.9387
# Epoch 9/150
# 6/6 [==============================] - 160s 27s/step - loss: 0.1995 - acc: 0.9308 - val_loss: 0.6075 - val_acc: 0.9450
# Epoch 10/150
# 6/6 [==============================] - 161s 27s/step - loss: 0.1916 - acc: 0.9339 - val_loss: 0.6659 - val_acc: 0.9457
#
# Epoch 00010: val_loss improved from 0.69315 to 0.66589, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 11/150
# 6/6 [==============================] - 162s 27s/step - loss: 0.1879 - acc: 0.9350 - val_loss: 0.6742 - val_acc: 0.9399
# Epoch 12/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.1872 - acc: 0.9363 - val_loss: 0.6728 - val_acc: 0.9415
# Epoch 13/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.1841 - acc: 0.9363 - val_loss: 0.6573 - val_acc: 0.9378
# Epoch 14/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1905 - acc: 0.9356 - val_loss: 0.6604 - val_acc: 0.9048
# Epoch 15/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1711 - acc: 0.9430 - val_loss: 0.5861 - val_acc: 0.8349
#
# Epoch 00015: val_loss improved from 0.66589 to 0.58608, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 16/150
# 6/6 [==============================] - 175s 29s/step - loss: 0.1775 - acc: 0.9403 - val_loss: 0.6356 - val_acc: 0.6253
# Epoch 17/150
# 6/6 [==============================] - 178s 30s/step - loss: 0.1717 - acc: 0.9413 - val_loss: 0.7296 - val_acc: 0.3470
# Epoch 18/150
# 6/6 [==============================] - 179s 30s/step - loss: 0.1665 - acc: 0.9445 - val_loss: 0.7657 - val_acc: 0.4857
# Epoch 19/150
# 6/6 [==============================] - 182s 30s/step - loss: 0.1694 - acc: 0.9433 - val_loss: 1.2750 - val_acc: 0.3019
# Epoch 20/150
# 6/6 [==============================] - 176s 29s/step - loss: 0.1594 - acc: 0.9467 - val_loss: 1.5035 - val_acc: 0.2660
#
# Epoch 00020: val_loss did not improve from 0.58608
# Epoch 21/150
# 6/6 [==============================] - 175s 29s/step - loss: 0.1578 - acc: 0.9478 - val_loss: 1.7080 - val_acc: 0.2603
# Epoch 22/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1551 - acc: 0.9485 - val_loss: 2.4984 - val_acc: 0.1555
# Epoch 23/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1722 - acc: 0.9425 - val_loss: 2.3732 - val_acc: 0.2032
# Epoch 24/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1585 - acc: 0.9461 - val_loss: 2.1283 - val_acc: 0.2511
# Epoch 25/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1556 - acc: 0.9483 - val_loss: 2.1702 - val_acc: 0.2238
#
# Epoch 00025: val_loss did not improve from 0.58608
# Epoch 26/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1567 - acc: 0.9467 - val_loss: 2.4803 - val_acc: 0.1830
# Epoch 27/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1440 - acc: 0.9532 - val_loss: 1.9044 - val_acc: 0.3147
# Epoch 28/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1438 - acc: 0.9517 - val_loss: 1.7669 - val_acc: 0.3594
# Epoch 29/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1483 - acc: 0.9504 - val_loss: 2.1006 - val_acc: 0.3153
# Epoch 30/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1437 - acc: 0.9534 - val_loss: 2.0607 - val_acc: 0.2726
#
# Epoch 00030: val_loss did not improve from 0.58608
# Epoch 31/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1464 - acc: 0.9519 - val_loss: 1.7683 - val_acc: 0.4418
# Epoch 32/150
# 6/6 [==============================] - 176s 29s/step - loss: 0.1428 - acc: 0.9515 - val_loss: 0.6568 - val_acc: 0.7439
# Epoch 33/150
# 6/6 [==============================] - 177s 30s/step - loss: 0.1300 - acc: 0.9576 - val_loss: 0.8983 - val_acc: 0.4318
# Epoch 34/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1578 - acc: 0.9478 - val_loss: 1.9619 - val_acc: 0.3180
# Epoch 35/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1339 - acc: 0.9571 - val_loss: 1.9849 - val_acc: 0.4036
#
# Epoch 00035: val_loss did not improve from 0.58608
# Epoch 36/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.1377 - acc: 0.9548 - val_loss: 3.0328 - val_acc: 0.2396
# Epoch 37/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1364 - acc: 0.9536 - val_loss: 2.1835 - val_acc: 0.2926
# Epoch 38/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.1277 - acc: 0.9577 - val_loss: 2.9555 - val_acc: 0.2736
# Epoch 39/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1356 - acc: 0.9547 - val_loss: 3.1812 - val_acc: 0.2171
# Epoch 40/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1323 - acc: 0.9554 - val_loss: 2.5555 - val_acc: 0.2405
#
# Epoch 00040: val_loss did not improve from 0.58608
# Epoch 41/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1266 - acc: 0.9570 - val_loss: 2.5649 - val_acc: 0.2957
# Epoch 42/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1359 - acc: 0.9537 - val_loss: 0.9166 - val_acc: 0.5396
# Epoch 43/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1231 - acc: 0.9581 - val_loss: 2.5039 - val_acc: 0.3046
# Epoch 44/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1379 - acc: 0.9539 - val_loss: 0.8433 - val_acc: 0.5809
# Epoch 45/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1232 - acc: 0.9580 - val_loss: 1.3294 - val_acc: 0.5427
#
# Epoch 00045: val_loss did not improve from 0.58608
# Epoch 46/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1331 - acc: 0.9549 - val_loss: 0.8395 - val_acc: 0.6136
# Epoch 47/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.1106 - acc: 0.9621 - val_loss: 1.0408 - val_acc: 0.5742
# Epoch 48/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1113 - acc: 0.9628 - val_loss: 0.2117 - val_acc: 0.9230
# Epoch 49/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1169 - acc: 0.9586 - val_loss: 0.3618 - val_acc: 0.8212
# Epoch 50/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.1131 - acc: 0.9626 - val_loss: 0.2789 - val_acc: 0.8799
#
# Epoch 00050: val_loss improved from 0.58608 to 0.27892, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 51/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1148 - acc: 0.9606 - val_loss: 0.7989 - val_acc: 0.6410
# Epoch 52/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1129 - acc: 0.9622 - val_loss: 0.7752 - val_acc: 0.7494
# Epoch 53/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.1156 - acc: 0.9608 - val_loss: 0.3977 - val_acc: 0.8156
# Epoch 54/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.1057 - acc: 0.9642 - val_loss: 0.2499 - val_acc: 0.8997
# Epoch 55/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.1102 - acc: 0.9610 - val_loss: 0.1690 - val_acc: 0.9521
#
# Epoch 00055: val_loss improved from 0.27892 to 0.16899, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 56/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1024 - acc: 0.9643 - val_loss: 0.1640 - val_acc: 0.9482
# Epoch 57/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.1063 - acc: 0.9630 - val_loss: 0.2416 - val_acc: 0.8908
# Epoch 58/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.1053 - acc: 0.9628 - val_loss: 0.3935 - val_acc: 0.8173
# Epoch 59/150
# 6/6 [==============================] - 169s 28s/step - loss: 0.1050 - acc: 0.9627 - val_loss: 0.2105 - val_acc: 0.9162
# Epoch 60/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.1062 - acc: 0.9631 - val_loss: 0.1375 - val_acc: 0.9533
#
# Epoch 00060: val_loss improved from 0.16899 to 0.13749, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 61/150
# 6/6 [==============================] - 169s 28s/step - loss: 0.0959 - acc: 0.9659 - val_loss: 0.2063 - val_acc: 0.9273
# Epoch 62/150
# 6/6 [==============================] - 169s 28s/step - loss: 0.0902 - acc: 0.9675 - val_loss: 0.5109 - val_acc: 0.7593
# Epoch 63/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0950 - acc: 0.9654 - val_loss: 0.3857 - val_acc: 0.8382
# Epoch 64/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0916 - acc: 0.9679 - val_loss: 0.4289 - val_acc: 0.7956
# Epoch 65/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0958 - acc: 0.9645 - val_loss: 0.8090 - val_acc: 0.6755
#
# Epoch 00065: val_loss did not improve from 0.13749
# Epoch 66/150
# 6/6 [==============================] - 169s 28s/step - loss: 0.0879 - acc: 0.9694 - val_loss: 0.8203 - val_acc: 0.7003
# Epoch 67/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0836 - acc: 0.9703 - val_loss: 0.4399 - val_acc: 0.8124
# Epoch 68/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0977 - acc: 0.9646 - val_loss: 0.3520 - val_acc: 0.8653
# Epoch 69/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0827 - acc: 0.9707 - val_loss: 1.0139 - val_acc: 0.7437
# Epoch 70/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0873 - acc: 0.9684 - val_loss: 0.3033 - val_acc: 0.8517
#
# Epoch 00070: val_loss did not improve from 0.13749
# Epoch 71/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0843 - acc: 0.9703 - val_loss: 0.3520 - val_acc: 0.8825
# Epoch 72/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0867 - acc: 0.9681 - val_loss: 0.8561 - val_acc: 0.6696
# Epoch 73/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.0831 - acc: 0.9693 - val_loss: 0.6371 - val_acc: 0.7758
# Epoch 74/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0785 - acc: 0.9727 - val_loss: 1.1249 - val_acc: 0.6483
# Epoch 75/150
# 6/6 [==============================] - 169s 28s/step - loss: 0.0680 - acc: 0.9754 - val_loss: 0.3431 - val_acc: 0.8784
#
# Epoch 00075: val_loss did not improve from 0.13749
# Epoch 76/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0695 - acc: 0.9753 - val_loss: 0.2061 - val_acc: 0.9230
# Epoch 77/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0617 - acc: 0.9774 - val_loss: 0.3237 - val_acc: 0.8982
# Epoch 78/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0551 - acc: 0.9798 - val_loss: 0.3547 - val_acc: 0.8663
# Epoch 79/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0603 - acc: 0.9777 - val_loss: 0.1596 - val_acc: 0.9335
# Epoch 80/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.0663 - acc: 0.9761 - val_loss: 0.2857 - val_acc: 0.9251
#
# Epoch 00080: val_loss did not improve from 0.13749
# Epoch 81/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0623 - acc: 0.9762 - val_loss: 0.3617 - val_acc: 0.8615
# Epoch 82/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.0604 - acc: 0.9783 - val_loss: 0.2744 - val_acc: 0.8955
# Epoch 83/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.0545 - acc: 0.9803 - val_loss: 0.2590 - val_acc: 0.9215
# Epoch 84/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0582 - acc: 0.9786 - val_loss: 0.2400 - val_acc: 0.9253
# Epoch 85/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.0602 - acc: 0.9773 - val_loss: 0.4020 - val_acc: 0.8579
#
# Epoch 00085: val_loss did not improve from 0.13749
# Epoch 86/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0554 - acc: 0.9794 - val_loss: 0.2291 - val_acc: 0.9400
# Epoch 87/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0582 - acc: 0.9783 - val_loss: 0.2810 - val_acc: 0.9509
# Epoch 88/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0557 - acc: 0.9792 - val_loss: 0.2772 - val_acc: 0.9488
# Epoch 89/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.0539 - acc: 0.9799 - val_loss: 0.2790 - val_acc: 0.9529
# Epoch 90/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0478 - acc: 0.9821 - val_loss: 0.2670 - val_acc: 0.9529
#
# Epoch 00090: val_loss did not improve from 0.13749
# Epoch 91/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0458 - acc: 0.9828 - val_loss: 0.3530 - val_acc: 0.9508
# Epoch 92/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0455 - acc: 0.9834 - val_loss: 0.2606 - val_acc: 0.9542
# Epoch 93/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0513 - acc: 0.9823 - val_loss: 0.2048 - val_acc: 0.9533
# Epoch 94/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0539 - acc: 0.9810 - val_loss: 0.2834 - val_acc: 0.9514
# Epoch 95/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0431 - acc: 0.9849 - val_loss: 0.3343 - val_acc: 0.9521
#
# Epoch 00095: val_loss did not improve from 0.13749
# Epoch 96/150
# 6/6 [==============================] - 177s 29s/step - loss: 0.0425 - acc: 0.9846 - val_loss: 0.3157 - val_acc: 0.9545
# Epoch 97/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0400 - acc: 0.9852 - val_loss: 0.3323 - val_acc: 0.9481
# Epoch 98/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.0337 - acc: 0.9875 - val_loss: 0.2533 - val_acc: 0.9559
# Epoch 99/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.0359 - acc: 0.9866 - val_loss: 0.2608 - val_acc: 0.9478
# Epoch 100/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.0306 - acc: 0.9887 - val_loss: 0.2612 - val_acc: 0.9587
#
# Epoch 00100: val_loss did not improve from 0.13749
# Epoch 101/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0318 - acc: 0.9885 - val_loss: 0.2859 - val_acc: 0.9399
# Epoch 102/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.0243 - acc: 0.9912 - val_loss: 0.3330 - val_acc: 0.9513
# Epoch 103/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0298 - acc: 0.9887 - val_loss: 0.2783 - val_acc: 0.9560
# Epoch 104/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0275 - acc: 0.9902 - val_loss: 0.3268 - val_acc: 0.9508
# Epoch 105/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0239 - acc: 0.9907 - val_loss: 0.3831 - val_acc: 0.9449
#
# Epoch 00105: val_loss did not improve from 0.13749
# Epoch 106/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0213 - acc: 0.9921 - val_loss: 0.2824 - val_acc: 0.9546
# Epoch 107/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0261 - acc: 0.9898 - val_loss: 0.2682 - val_acc: 0.9560
# Epoch 108/150
# 6/6 [==============================] - 164s 27s/step - loss: 0.0225 - acc: 0.9911 - val_loss: 0.2850 - val_acc: 0.9529
# Epoch 109/150
# 6/6 [==============================] - 163s 27s/step - loss: 0.0270 - acc: 0.9897 - val_loss: 0.2890 - val_acc: 0.9498
# Epoch 110/150
# 6/6 [==============================] - 162s 27s/step - loss: 0.0281 - acc: 0.9892 - val_loss: 0.2582 - val_acc: 0.9516
#
# Epoch 00110: val_loss did not improve from 0.13749
# Epoch 111/150
# 6/6 [==============================] - 164s 27s/step - loss: 0.0276 - acc: 0.9894 - val_loss: 0.3090 - val_acc: 0.9502
# Epoch 112/150
# 6/6 [==============================] - 162s 27s/step - loss: 0.0286 - acc: 0.9897 - val_loss: 0.3240 - val_acc: 0.9372
# Epoch 113/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0285 - acc: 0.9888 - val_loss: 0.3830 - val_acc: 0.9014
# Epoch 114/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0289 - acc: 0.9889 - val_loss: 0.2171 - val_acc: 0.9620
# Epoch 115/150
# 6/6 [==============================] - 165s 28s/step - loss: 0.0301 - acc: 0.9882 - val_loss: 0.1804 - val_acc: 0.9613
#
# Epoch 00115: val_loss did not improve from 0.13749
# Epoch 116/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0332 - acc: 0.9877 - val_loss: 0.2656 - val_acc: 0.9540
# Epoch 117/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0294 - acc: 0.9890 - val_loss: 0.2591 - val_acc: 0.9523
# Epoch 118/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0293 - acc: 0.9890 - val_loss: 0.2897 - val_acc: 0.9542
# Epoch 119/150
# 6/6 [==============================] - 167s 28s/step - loss: 0.0239 - acc: 0.9910 - val_loss: 0.2932 - val_acc: 0.9550
# Epoch 120/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.0208 - acc: 0.9918 - val_loss: 0.1972 - val_acc: 0.9610
#
# Epoch 00120: val_loss did not improve from 0.13749
# Epoch 121/150
# 6/6 [==============================] - 168s 28s/step - loss: 0.0192 - acc: 0.9924 - val_loss: 0.2936 - val_acc: 0.9550
# Epoch 122/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.0186 - acc: 0.9928 - val_loss: 0.2540 - val_acc: 0.9557
# Epoch 123/150
# 6/6 [==============================] - 175s 29s/step - loss: 0.0210 - acc: 0.9917 - val_loss: 0.2638 - val_acc: 0.9601
# Epoch 124/150
# 6/6 [==============================] - 176s 29s/step - loss: 0.0162 - acc: 0.9940 - val_loss: 0.3111 - val_acc: 0.9590
# Epoch 125/150
# 6/6 [==============================] - 176s 29s/step - loss: 0.0200 - acc: 0.9925 - val_loss: 0.3514 - val_acc: 0.9586
#
# Epoch 00125: val_loss did not improve from 0.13749
# Epoch 126/150
# 6/6 [==============================] - 176s 29s/step - loss: 0.0168 - acc: 0.9936 - val_loss: 0.2707 - val_acc: 0.9612
# Epoch 127/150
# 6/6 [==============================] - 179s 30s/step - loss: 0.0197 - acc: 0.9923 - val_loss: 0.2481 - val_acc: 0.9587
# Epoch 128/150
# 6/6 [==============================] - 175s 29s/step - loss: 0.0164 - acc: 0.9939 - val_loss: 0.3200 - val_acc: 0.9565
# Epoch 129/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0148 - acc: 0.9939 - val_loss: 0.3030 - val_acc: 0.9548
# Epoch 130/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.0143 - acc: 0.9943 - val_loss: 0.3266 - val_acc: 0.9585
#
# Epoch 00130: val_loss did not improve from 0.13749
# Epoch 131/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.0162 - acc: 0.9940 - val_loss: 0.2381 - val_acc: 0.9613
# Epoch 132/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.0182 - acc: 0.9926 - val_loss: 0.2480 - val_acc: 0.9575
# Epoch 133/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0207 - acc: 0.9924 - val_loss: 0.2789 - val_acc: 0.9564
# Epoch 134/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.0228 - acc: 0.9915 - val_loss: 0.2951 - val_acc: 0.9552
# Epoch 135/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.0193 - acc: 0.9927 - val_loss: 0.3135 - val_acc: 0.9582
#
# Epoch 00135: val_loss did not improve from 0.13749
# Epoch 136/150
# 6/6 [==============================] - 171s 28s/step - loss: 0.0155 - acc: 0.9939 - val_loss: 0.3166 - val_acc: 0.9581
# Epoch 137/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0154 - acc: 0.9939 - val_loss: 0.1534 - val_acc: 0.9673
# Epoch 138/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0134 - acc: 0.9948 - val_loss: 0.2425 - val_acc: 0.9618
# Epoch 139/150
# 6/6 [==============================] - 175s 29s/step - loss: 0.0159 - acc: 0.9938 - val_loss: 0.1994 - val_acc: 0.9613
# Epoch 140/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0134 - acc: 0.9947 - val_loss: 0.2890 - val_acc: 0.9561
#
# Epoch 00140: val_loss did not improve from 0.13749
# Epoch 141/150
# 6/6 [==============================] - 172s 29s/step - loss: 0.0116 - acc: 0.9952 - val_loss: 0.2184 - val_acc: 0.9632
# Epoch 142/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0126 - acc: 0.9950 - val_loss: 0.3500 - val_acc: 0.9569
# Epoch 143/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.0116 - acc: 0.9952 - val_loss: 0.2191 - val_acc: 0.9633
# Epoch 144/150
# 6/6 [==============================] - 173s 29s/step - loss: 0.0138 - acc: 0.9945 - val_loss: 0.2273 - val_acc: 0.9591
# Epoch 145/150
# 6/6 [==============================] - 171s 29s/step - loss: 0.0126 - acc: 0.9947 - val_loss: 0.2747 - val_acc: 0.9589
#
# Epoch 00145: val_loss did not improve from 0.13749
# Epoch 146/150
# 6/6 [==============================] - 174s 29s/step - loss: 0.0114 - acc: 0.9952 - val_loss: 0.3265 - val_acc: 0.9593
# Epoch 147/150
# 6/6 [==============================] - 170s 28s/step - loss: 0.0089 - acc: 0.9965 - val_loss: 0.2726 - val_acc: 0.9665
# Epoch 148/150
# 6/6 [==============================] - 166s 28s/step - loss: 0.0115 - acc: 0.9951 - val_loss: 0.2318 - val_acc: 0.9622
# Epoch 149/150
# 6/6 [==============================] - 165s 27s/step - loss: 0.0090 - acc: 0.9963 - val_loss: 0.2848 - val_acc: 0.9604
# Epoch 150/150
# 6/6 [==============================] - 164s 27s/step - loss: 0.0113 - acc: 0.9962 - val_loss: 0.2468 - val_acc: 0.9614
#
# Epoch 00150: val_loss did not improve from 0.13749

# %%
RESULT_NAME_1 = 'results'

RESULT_TYPE_MASK = 'predict_outputs'
RESULT_TYPE_ARGMAX = 'argmax_outputs'
RESULT_TYPE_OVERLAY = 'overlay_outputs'

DATATYPE_TRAIN = 'train'
DATATYPE_VALID = 'valid'

def DATATYPE_PREDICTS(data_type):
    return data_type + '_predicts'

def DATATYPE_TEACHERS(data_type):
    return data_type + '_teachers'

IDX_CLASS_CANCER = 0
IDXES = [IDX_CLASS_CANCER]

def RESULTS_DIR(result_name, data_type, result_type):
    return os.path.join(result_name, data_type, result_type)


def eval_iou(result_name, data_type):
    pred_mask_dir = RESULTS_DIR(result_name, DATATYPE_PREDICTS(data_type), RESULT_TYPE_MASK)
    teacher_mask_dir = RESULTS_DIR(result_name, DATATYPE_TEACHERS(data_type), RESULT_TYPE_MASK)
    if not os.path.exists(teacher_mask_dir):
        print('teachers dir is not found. : ', teacher_mask_dir)
        return False

    print('target pred dir : ', pred_mask_dir)

    pred_mask_files = glob.glob(os.path.join(pred_mask_dir, '*.png'))
    pred_mask_files.sort()

    all_ious = {}
    for target_idx in IDXES:
        all_ious[target_idx] = []

    if len(pred_mask_files) < 1:
        print('pred_mask_files is []')

    for p_mask_file in pred_mask_files:
        fname = os.path.basename(p_mask_file)
        t_mask_file = os.path.join(teacher_mask_dir, fname)
        if not os.path.exists(t_mask_file):
            print('teacher mask is not found.')
            continue

        p_masks = cv2.imread(p_mask_file)
        t_masks = cv2.imread(t_mask_file)

        iou_print = ','
        for target_idx in IDXES:
            p_mask = p_masks[:, :, target_idx]
            t_mask = t_masks[:, :, target_idx]
            iou = calculate_iou(p_mask, t_mask)
            iou_print += '%.3f, ' % iou
            if np.isnan(iou):
                continue
            all_ious[target_idx].append(iou)

        print(fname, iou_print)

    mean_iou_print = 'mean:'
    for target_idx in IDXES:
        mean_iou = np.average(np.array(all_ious[target_idx]))
        mean_iou_print += '%.3f, ' % mean_iou
    print('')
    print(mean_iou_print)


def calculate_iou(p_mask, t_mask):
    p_mask = to_binary(p_mask)
    t_mask = to_binary(t_mask)

    if np.sum(t_mask) == 0:
        return np.nan

    overlap = np.sum(p_mask * t_mask)
    union = np.sum(to_binary(p_mask + t_mask))

    return overlap / union


def to_binary(mask, val=1):
    mask[mask > 0] = val
    return mask

# %%
eval_iou(RESULT_NAME_1, DATATYPE_TRAIN)
# Out:
# target pred dir :  results/train_predicts/predict_outputs
# benign1.png ,0.702,
# benign10.png ,0.814,
# benign101.png ,0.832,
# benign104.png ,0.511,
# benign105.png ,0.818,
# benign107.png ,0.800,
# benign108.png ,0.000,
# benign11.png ,0.678,
# benign110.png ,0.625,
# benign111.png ,0.827,
# benign112.png ,0.744,
# benign113.png ,0.898,
# benign114.png ,0.000,
# benign115.png ,0.776,
# benign116.png ,0.000,
# benign118.png ,0.000,
# benign119.png ,0.000,
# benign12.png ,0.754,
# benign120.png ,0.597,
# benign122.png ,0.000,
# benign123.png ,0.408,
# benign124.png ,0.023,
# benign126.png ,0.746,
# benign127.png ,0.274,
# benign128.png ,0.676,
# benign129.png ,0.851,
# benign130.png ,0.905,
# benign131.png ,0.012,
# benign132.png ,0.815,
# benign134.png ,0.608,
# benign135.png ,0.892,
# benign137.png ,0.816,
# benign138.png ,0.912,
# benign139.png ,0.805,
# benign14.png ,0.609,
# benign140.png ,0.352,
# benign141.png ,0.050,
# benign143.png ,0.730,
# benign144.png ,0.179,
# benign145.png ,0.764,
# benign146.png ,0.574,
# benign147.png ,0.000,
# benign148.png ,0.800,
# benign149.png ,0.784,
# benign15.png ,0.832,
# benign150.png ,0.580,
# benign151.png ,0.764,
# benign153.png ,0.449,
# benign154.png ,0.628,
# benign155.png ,0.604,
# benign157.png ,0.826,
# benign158.png ,0.734,
# benign160.png ,0.692,
# benign161.png ,0.808,
# benign162.png ,0.518,
# benign163.png ,0.113,
# benign164.png ,0.255,
# benign166.png ,0.351,
# benign167.png ,0.621,
# benign168.png ,0.839,
# benign169.png ,0.000,
# benign170.png ,0.729,
# benign171.png ,0.345,
# benign172.png ,0.718,
# benign174.png ,0.795,
# benign175.png ,0.833,
# benign176.png ,0.586,
# benign178.png ,0.555,
# benign179.png ,0.000,
# benign18.png ,0.493,
# benign180.png ,0.828,
# benign181.png ,0.666,
# benign182.png ,0.705,
# benign183.png ,0.000,
# benign184.png ,0.809,
# benign185.png ,0.275,
# benign186.png ,0.794,
# benign187.png ,0.478,
# benign188.png ,0.111,
# benign189.png ,0.662,
# benign19.png ,0.719,
# benign190.png ,0.360,
# benign192.png ,0.900,
# benign194.png ,0.696,
# benign196.png ,0.099,
# benign197.png ,0.269,
# benign198.png ,0.773,
# benign199.png ,0.000,
# benign2.png ,0.825,
# benign20.png ,0.834,
# benign200.png ,0.522,
# benign201.png ,0.000,
# benign202.png ,0.358,
# benign203.png ,0.000,
# benign205.png ,0.000,
# benign206.png ,0.019,
# benign207.png ,0.000,
# benign208.png ,0.799,
# benign209.png ,0.746,
# benign21.png ,0.565,
# benign210.png ,0.000,
# benign212.png ,0.000,
# benign213.png ,0.748,
# benign214.png ,0.563,
# benign215.png ,0.753,
# benign217.png ,0.663,
# benign218.png ,0.536,
# benign219.png ,0.000,
# benign22.png ,0.835,
# benign220.png ,0.165,
# benign222.png ,0.229,
# benign223.png ,0.000,
# benign224.png ,0.000,
# benign225.png ,0.000,
# benign226.png ,0.280,
# benign227.png ,0.657,
# benign228.png ,0.047,
# benign229.png ,0.891,
# benign23.png ,0.798,
# benign230.png ,0.717,
# benign231.png ,0.849,
# benign233.png ,0.000,
# benign234.png ,0.521,
# benign235.png ,0.000,
# benign236.png ,0.003,
# benign237.png ,0.526,
# benign238.png ,0.671,
# benign24.png ,0.885,
# benign240.png ,0.208,
# benign241.png ,0.528,
# benign242.png ,0.037,
# benign243.png ,0.000,
# benign244.png ,0.287,
# benign245.png ,0.539,
# benign247.png ,0.000,
# benign248.png ,0.000,
# benign249.png ,0.006,
# benign25.png ,0.333,
# benign250.png ,0.485,
# benign252.png ,0.705,
# benign254.png ,0.517,
# benign255.png ,0.246,
# benign256.png ,0.000,
# benign257.png ,0.000,
# benign258.png ,0.588,
# benign259.png ,0.871,
# benign26.png ,0.761,
# benign261.png ,0.562,
# benign262.png ,0.002,
# benign263.png ,0.014,
# benign264.png ,0.393,
# benign266.png ,0.532,
# benign268.png ,0.639,
# benign269.png ,0.000,
# benign27.png ,0.853,
# benign270.png ,0.724,
# benign271.png ,0.197,
# benign272.png ,0.000,
# benign274.png ,0.481,
# benign275.png ,0.729,
# benign276.png ,0.756,
# benign277.png ,0.251,
# benign278.png ,0.495,
# benign279.png ,0.502,
# benign28.png ,0.791,
# benign280.png ,0.843,
# benign281.png ,0.606,
# benign282.png ,0.037,
# benign284.png ,0.547,
# benign285.png ,0.579,
# benign287.png ,0.696,
# benign288.png ,0.000,
# benign289.png ,0.000,
# benign29.png ,0.224,
# benign291.png ,0.876,
# benign292.png ,0.000,
# benign293.png ,0.000,
# benign294.png ,0.000,
# benign295.png ,0.883,
# benign297.png ,0.764,
# benign298.png ,0.000,
# benign299.png ,0.000,
# benign3.png ,0.836,
# benign30.png ,0.653,
# benign301.png ,0.360,
# benign302.png ,0.000,
# benign303.png ,0.038,
# benign304.png ,0.000,
# benign305.png ,0.510,
# benign306.png ,0.003,
# benign308.png ,0.514,
# benign309.png ,0.012,
# benign31.png ,0.636,
# benign310.png ,0.333,
# benign312.png ,0.054,
# benign313.png ,0.000,
# benign314.png ,0.139,
# benign315.png ,0.166,
# benign316.png ,0.000,
# benign317.png ,0.092,
# benign319.png ,0.797,
# benign32.png ,0.000,
# benign320.png ,0.878,
# benign321.png ,0.285,
# benign323.png ,0.842,
# benign324.png ,0.627,
# benign326.png ,0.804,
# benign327.png ,0.822,
# benign328.png ,0.752,
# benign33.png ,0.923,
# benign330.png ,0.679,
# benign331.png ,0.591,
# benign332.png ,0.833,
# benign333.png ,0.196,
# benign334.png ,0.000,
# benign335.png ,0.011,
# benign337.png ,0.237,
# benign338.png ,0.050,
# benign339.png ,0.540,
# benign34.png ,0.820,
# benign340.png ,0.747,
# benign342.png ,0.005,
# benign343.png ,0.000,
# benign344.png ,0.000,
# benign345.png ,0.074,
# benign347.png ,0.000,
# benign348.png ,0.199,
# benign349.png ,0.070,
# benign35.png ,0.277,
# benign351.png ,0.000,
# benign353.png ,0.222,
# benign354.png ,0.073,
# benign356.png ,0.217,
# benign357.png ,0.122,
# benign358.png ,0.000,
# benign359.png ,0.572,
# benign36.png ,0.644,
# benign361.png ,0.000,
# benign362.png ,0.005,
# benign364.png ,0.496,
# benign367.png ,0.003,
# benign368.png ,0.000,
# benign369.png ,0.477,
# benign37.png ,0.367,
# benign370.png ,0.404,
# benign372.png ,0.320,
# benign373.png ,0.845,
# benign375.png ,0.111,
# benign376.png ,0.178,
# benign378.png ,0.153,
# benign380.png ,0.380,
# benign381.png ,0.246,
# benign382.png ,0.093,
# benign384.png ,0.342,
# benign386.png ,0.633,
# benign387.png ,0.882,
# benign388.png ,0.027,
# benign389.png ,0.025,
# benign39.png ,0.752,
# benign390.png ,0.573,
# benign391.png ,0.000,
# benign392.png ,0.022,
# benign393.png ,0.463,
# benign394.png ,0.000,
# benign396.png ,0.000,
# benign397.png ,0.000,
# benign398.png ,0.204,
# benign399.png ,0.360,
# benign40.png ,0.784,
# benign400.png ,0.231,
# benign401.png ,0.169,
# benign402.png ,0.183,
# benign403.png ,0.455,
# benign404.png ,0.207,
# benign405.png ,0.401,
# benign406.png ,0.344,
# benign408.png ,0.000,
# benign409.png ,0.000,
# benign41.png ,0.259,
# benign410.png ,0.000,
# benign411.png ,0.049,
# benign412.png ,0.209,
# benign413.png ,0.000,
# benign414.png ,0.119,
# benign415.png ,0.207,
# benign418.png ,0.000,
# benign419.png ,0.838,
# benign42.png ,0.007,
# benign420.png ,0.102,
# benign422.png ,0.006,
# benign423.png ,0.308,
# benign424.png ,0.552,
# benign425.png ,0.699,
# benign426.png ,0.000,
# benign428.png ,0.631,
# benign429.png ,0.810,
# benign431.png ,0.631,
# benign432.png ,0.879,
# benign434.png ,0.629,
# benign437.png ,0.364,
# benign45.png ,0.620,
# benign47.png ,0.710,
# benign48.png ,0.772,
# benign49.png ,0.525,
# benign50.png ,0.723,
# benign52.png ,0.571,
# benign53.png ,0.673,
# benign54.png ,0.816,
# benign55.png ,0.879,
# benign56.png ,0.599,
# benign57.png ,0.573,
# benign58.png ,0.644,
# benign59.png ,0.822,
# benign6.png ,0.855,
# benign60.png ,0.722,
# benign61.png ,0.000,
# benign62.png ,0.349,
# benign63.png ,0.415,
# benign64.png ,0.049,
# benign65.png ,0.842,
# benign66.png ,0.861,
# benign67.png ,0.563,
# benign69.png ,0.479,
# benign7.png ,0.608,
# benign70.png ,0.579,
# benign71.png ,0.000,
# benign73.png ,0.531,
# benign75.png ,0.916,
# benign76.png ,0.819,
# benign77.png ,0.664,
# benign79.png ,0.079,
# benign81.png ,0.305,
# benign82.png ,0.685,
# benign83.png ,0.379,
# benign84.png ,0.553,
# benign85.png ,0.299,
# benign86.png ,0.369,
# benign87.png ,0.241,
# benign88.png ,0.254,
# benign89.png ,0.804,
# benign9.png ,0.781,
# benign90.png ,0.000,
# benign91.png ,0.523,
# benign92.png ,0.638,
# benign93.png ,0.466,
# benign94.png ,0.000,
# benign95.png ,0.894,
# benign96.png ,0.616,
# benign97.png ,0.171,
#
# mean:0.421,

# %%
from enum import Enum

EVAL_EXCESS_DIR = 'eval_excess'
EVAL_DEFICIENCY_DIR = 'eval_deficiency'
EVAL_EXCESS_AND_DEFICIENCY_DIR = 'eval_excess_and_deficiency'

CLASS_NAME_CANCER = 'CANCER'
CLASS_NAMES = [CLASS_NAME_CANCER]


class OutputType(Enum):
    TEXT = 0
    IMAGE = 1
    BOTH = 2


def prepare_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    return dir_path


def eval_excesses_and_deficiencies(result_name, data_type,output_type=OutputType.TEXT, with_save=False):
    pred_mask_dir = RESULTS_DIR(result_name, DATATYPE_PREDICTS(data_type), RESULT_TYPE_MASK)
    teacher_mask_dir = RESULTS_DIR(result_name, DATATYPE_TEACHERS(data_type), RESULT_TYPE_MASK)

    print('target pred dir : ', pred_mask_dir)

    pred_mask_files = glob.glob(os.path.join(pred_mask_dir, '*.png'))
    pred_mask_files.sort()

    all_excesses = {}
    all_deficiencies = {}
    all_deficiencies_to_teacher = {}
    count_teachers = {}

    for target_idx in IDXES:
        all_excesses[target_idx] = []
        all_deficiencies[target_idx] = []
        all_deficiencies_to_teacher[target_idx] = []
        count_teachers[target_idx] = 0


    if len(pred_mask_files) < 1:
        print('pred_mask_files is []')

    for k, p_mask_file in enumerate(pred_mask_files):
        fname = os.path.basename(p_mask_file)
        t_mask_file = os.path.join(teacher_mask_dir, fname)
        if not os.path.exists(t_mask_file):
            print('teacher mask is not found.')
            continue

        p_masks = cv2.imread(p_mask_file)
        t_masks = cv2.imread(t_mask_file)

#         save_base_dir = RESULTS_DIR(result_name, model_type, data_type, '')
        save_base_dir = "results"
        eval_excess_and_deficiency(fname, p_masks, t_masks, all_excesses, all_deficiencies,
                    all_deficiencies_to_teacher, count_teachers,
                    output_type=output_type, with_save=with_save, save_base_dir=save_base_dir)

    if output_type == OutputType.TEXT or output_type == OutputType.BOTH:
        mean_excesses_print = ':'
        mean_deficiencies_print = ':'
        mean_deficiencies_to_teacher_print = ':'
        excesses_rate_print = ':'
        deficiencies_rate_print = ':'
        deficiencies_to_teacher_rate_print = ':'
        for target_idx in IDXES:
            mean_excesses = np.average(np.array(all_excesses[target_idx]))
            mean_deficiencies = np.average(np.array(all_deficiencies[target_idx]))
            mean_deficiencies_to_teacher = np.average(np.array(all_deficiencies_to_teacher[target_idx]))
            mean_excesses_print += '%.3f, ' % mean_excesses
            mean_deficiencies_print += '%.3f, ' % mean_deficiencies
            mean_deficiencies_to_teacher_print += '%.3f, ' % mean_deficiencies_to_teacher
            excesses_rate_print += '%.3f, ' % (len(all_excesses[target_idx]) / len(pred_mask_files))
            deficiencies_rate_print += '%.3f, ' % (len(all_deficiencies[target_idx]) / len(pred_mask_files))
            deficiencies_to_teacher_rate = 0
            if count_teachers[target_idx] != 0:
                deficiencies_to_teacher_rate = len(all_deficiencies[target_idx]) / count_teachers[target_idx]
            deficiencies_to_teacher_rate_print += '%.3f, ' % deficiencies_to_teacher_rate
        print('')
        print('rate:', excesses_rate_print, deficiencies_rate_print)
        print('mean:', mean_excesses_print, mean_deficiencies_print, mean_deficiencies_to_teacher_print)


def eval_excess_and_deficiency(fname, p_masks, t_masks, all_excesses, all_deficiencies,
                            all_deficiencies_to_teacher, count_teachers,
                            output_type=OutputType.TEXT, with_save=False, save_base_dir=''):
    img_h, img_w = np.shape(p_masks)[:2]
    img_size = img_h * img_w

    excesses_print = ','
    deficiencies_print = ','
    deficiencies_to_teacher_print = ','
    image_plotter = ImageLinePlotter(plot_area_num=len(IDXES))
    for target_idx, cname in zip(IDXES, CLASS_NAMES):
        p_mask = to_binary(p_masks[:, :, target_idx])
        t_mask = to_binary(t_masks[:, :, target_idx])
        e_mask, d_mask, o_mask = make_excess_and_deficiency(p_mask, t_mask)
        excesses = np.sum(e_mask) / img_size
        deficiencies = np.sum(d_mask) / img_size
        if np.sum(t_mask) != 0:
            count_teachers[target_idx] += 1
            deficiencies_to_teacher = np.sum(d_mask) / np.sum(t_mask)
        else:
            deficiencies_to_teacher = 0
        excesses_print += '%.3f, ' % excesses
        deficiencies_print += '%.3f, ' % deficiencies
        deficiencies_to_teacher_print += '%.3f, ' % deficiencies_to_teacher
        if excesses != 0:
            all_excesses[target_idx].append(excesses)
        if deficiencies != 0:
            all_deficiencies[target_idx].append(deficiencies)
        if deficiencies_to_teacher != 0:
            all_deficiencies_to_teacher[target_idx].append(deficiencies_to_teacher)
        dummy_mask = np.zeros(np.shape(p_mask)[:2], dtype=np.uint8)
        eval_img = np.stack([d_mask * 255, o_mask * 120, e_mask * 255], axis=2)
        eval_img = eval_img.astype(np.uint8)
        image_plotter.add_image(eval_img, title=cname)
        if with_save:
            e_img = np.stack([dummy_mask, dummy_mask, e_mask * 255], axis=2)
            d_img = np.stack([d_mask * 255, dummy_mask, dummy_mask], axis=2)
            save_excess_dir = prepare_dir(os.path.join(save_base_dir, EVAL_EXCESS_DIR))
            save_deficiency_dir = prepare_dir(os.path.join(save_base_dir, EVAL_DEFICIENCY_DIR))
            save_excess_and_deficiency_dir = prepare_dir(os.path.join(save_base_dir, EVAL_EXCESS_AND_DEFICIENCY_DIR))
            cv2.imwrite(os.path.join(save_excess_dir, fname), e_img)
            cv2.imwrite(os.path.join(save_deficiency_dir, fname), d_img)
            cv2.imwrite(os.path.join(save_excess_and_deficiency_dir, fname), eval_img)

    if output_type == OutputType.TEXT or output_type == OutputType.BOTH:
        print(fname, excesses_print, deficiencies_print, deficiencies_to_teacher_print)
    else:
        print(fname)

    if output_type == OutputType.IMAGE or output_type == OutputType.BOTH:
        image_plotter.show_plot()

    return all_excesses, all_deficiencies, all_deficiencies_to_teacher, count_teachers


def make_excess_and_deficiency(p_mask, t_mask):
    e_mask = (p_mask - t_mask).astype(np.int8)
    e_mask[e_mask < 0] = 0
    e_mask = e_mask.astype(np.uint8)

    d_mask = (t_mask - p_mask).astype(np.int8)
    d_mask[d_mask < 0] = 0
    d_mask = d_mask.astype(np.uint8)

    o_mask = p_mask * t_mask

    return e_mask, d_mask, o_mask

# %%
eval_excesses_and_deficiencies(RESULT_NAME_1, DATATYPE_VALID, output_type=OutputType.TEXT)
# Out:
# target pred dir :  results/valid_predicts/predict_outputs
# benign100.png ,0.013,  ,0.011,  ,0.233,
# benign102.png ,0.004,  ,0.047,  ,0.976,
# benign103.png ,0.023,  ,0.031,  ,0.278,
# benign106.png ,0.004,  ,0.002,  ,0.121,
# benign109.png ,0.041,  ,0.011,  ,0.103,
# benign117.png ,0.003,  ,0.002,  ,0.094,
# benign121.png ,0.000,  ,0.038,  ,0.860,
# benign125.png ,0.001,  ,0.004,  ,0.341,
# benign13.png ,0.002,  ,0.033,  ,0.243,
# benign133.png ,0.000,  ,0.001,  ,0.143,
# benign136.png ,0.008,  ,0.001,  ,0.043,
# benign142.png ,0.000,  ,0.001,  ,0.096,
# benign152.png ,0.004,  ,0.122,  ,0.516,
# benign156.png ,0.003,  ,0.000,  ,0.026,
# benign159.png ,0.003,  ,0.001,  ,0.080,
# benign16.png ,0.000,  ,0.001,  ,0.118,
# benign165.png ,0.002,  ,0.002,  ,0.346,
# benign17.png ,0.000,  ,0.006,  ,0.284,
# benign173.png ,0.089,  ,0.004,  ,0.192,
# benign177.png ,0.015,  ,0.005,  ,0.497,
# benign191.png ,0.000,  ,0.006,  ,0.356,
# benign193.png ,0.001,  ,0.009,  ,0.933,
# benign195.png ,0.024,  ,0.108,  ,0.713,
# benign204.png ,0.000,  ,0.046,  ,0.872,
# benign211.png ,0.000,  ,0.012,  ,0.697,
# benign216.png ,0.014,  ,0.017,  ,0.290,
# benign221.png ,0.091,  ,0.006,  ,0.697,
# benign232.png ,0.011,  ,0.044,  ,0.390,
# benign239.png ,0.013,  ,0.003,  ,0.142,
# benign246.png ,0.102,  ,0.005,  ,0.580,
# benign251.png ,0.000,  ,0.019,  ,0.903,
# benign253.png ,0.003,  ,0.005,  ,0.138,
# benign260.png ,0.029,  ,0.010,  ,0.184,
# benign265.png ,0.010,  ,0.021,  ,0.308,
# benign267.png ,0.044,  ,0.023,  ,0.596,
# benign273.png ,0.000,  ,0.105,  ,1.000,
# benign283.png ,0.000,  ,0.012,  ,1.000,
# benign286.png ,0.000,  ,0.063,  ,0.501,
# benign290.png ,0.003,  ,0.067,  ,0.507,
# benign296.png ,0.031,  ,0.050,  ,0.381,
# benign300.png ,0.006,  ,0.043,  ,0.446,
# benign307.png ,0.002,  ,0.004,  ,0.170,
# benign311.png ,0.000,  ,0.123,  ,0.867,
# benign318.png ,0.002,  ,0.000,  ,0.030,
# benign322.png ,0.001,  ,0.003,  ,0.296,
# benign325.png ,0.001,  ,0.004,  ,0.388,
# benign329.png ,0.000,  ,0.001,  ,0.188,
# benign336.png ,0.000,  ,0.040,  ,1.000,
# benign341.png ,0.000,  ,0.136,  ,0.929,
# benign346.png ,0.115,  ,0.004,  ,0.187,
# benign350.png ,0.000,  ,0.109,  ,0.809,
# benign352.png ,0.000,  ,0.011,  ,1.000,
# benign355.png ,0.000,  ,0.122,  ,0.866,
# benign360.png ,0.000,  ,0.039,  ,0.952,
# benign363.png ,0.000,  ,0.017,  ,0.783,
# benign365.png ,0.000,  ,0.030,  ,0.957,
# benign366.png ,0.001,  ,0.033,  ,0.458,
# benign371.png ,0.000,  ,0.186,  ,1.000,
# benign374.png ,0.000,  ,0.005,  ,1.000,
# benign377.png ,0.000,  ,0.014,  ,0.663,
# benign379.png ,0.026,  ,0.030,  ,0.986,
# benign38.png ,0.004,  ,0.000,  ,0.022,
# benign383.png ,0.012,  ,0.060,  ,1.000,
# benign385.png ,0.000,  ,0.039,  ,1.000,
# benign395.png ,0.000,  ,0.112,  ,0.952,
# benign4.png ,0.003,  ,0.003,  ,0.347,
# benign407.png ,0.000,  ,0.359,  ,1.000,
# benign416.png ,0.000,  ,0.030,  ,1.000,
# benign417.png ,0.000,  ,0.028,  ,1.000,
# benign421.png ,0.000,  ,0.138,  ,0.924,
# benign427.png ,0.091,  ,0.002,  ,0.055,
# benign43.png ,0.000,  ,0.004,  ,0.424,
# benign430.png ,0.002,  ,0.021,  ,0.524,
# benign433.png ,0.005,  ,0.009,  ,0.701,
# benign435.png ,0.000,  ,0.013,  ,0.848,
# benign436.png ,0.018,  ,0.088,  ,0.919,
# benign44.png ,0.000,  ,0.001,  ,0.050,
# benign46.png ,0.000,  ,0.002,  ,0.174,
# benign5.png ,0.000,  ,0.008,  ,0.612,
# benign51.png ,0.001,  ,0.002,  ,0.176,
# benign68.png ,0.012,  ,0.082,  ,0.414,
# benign72.png ,0.015,  ,0.002,  ,0.026,
# benign74.png ,0.001,  ,0.001,  ,0.111,
# benign78.png ,0.001,  ,0.002,  ,0.189,
# benign8.png ,0.000,  ,0.006,  ,0.497,
# benign80.png ,0.013,  ,0.133,  ,0.582,
# benign98.png ,0.146,  ,0.012,  ,0.247,
# benign99.png ,0.007,  ,0.001,  ,0.024,
#
# rate: :0.727,  :1.000,
# mean: :0.017,  :0.035,  :0.507,

# %%
eval_excesses_and_deficiencies(RESULT_NAME_1, DATATYPE_VALID, output_type=OutputType.IMAGE)
# Out:
# target pred dir :  results/valid_predicts/predict_outputs
# benign100.png
# benign102.png
# benign103.png
# benign106.png
# benign109.png
# benign117.png
# benign121.png
# benign125.png
# benign13.png
# benign133.png
# benign136.png
# benign142.png
# benign152.png
# benign156.png
# benign159.png
# benign16.png
# benign165.png
# benign17.png
# benign173.png
# benign177.png
# benign191.png
# benign193.png
# benign195.png
# benign204.png
# benign211.png
# benign216.png
# benign221.png
# benign232.png
# benign239.png
# benign246.png
# benign251.png
# benign253.png
# benign260.png
# benign265.png
# benign267.png
# benign273.png
# benign283.png
# benign286.png
# benign290.png
# benign296.png
# benign300.png
# benign307.png
# benign311.png
# benign318.png
# benign322.png
# benign325.png
# benign329.png
# benign336.png
# benign341.png
# benign346.png
# benign350.png
# benign352.png
# benign355.png
# benign360.png
# benign363.png
# benign365.png
# benign366.png
# benign371.png
# benign374.png
# benign377.png
# benign379.png
# benign38.png
# benign383.png
# benign385.png
# benign395.png
# benign4.png
# benign407.png
# benign416.png
# benign417.png
# benign421.png
# benign427.png
# benign43.png
# benign430.png
# benign433.png
# benign435.png
# benign436.png
# benign44.png
# benign46.png
# benign5.png
# benign51.png
# benign68.png
# benign72.png
# benign74.png
# benign78.png
# benign8.png
# benign80.png
# benign98.png
# benign99.png

# %% [markdown]
# arearatioの計算
