# %%
import os
import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageFilter


from utils.jupyter_utils import ImageLinePlotter

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
         print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.float32(np.array(Image.open(seg_file)))

    plotter = ImageLinePlotter(seg_file, plot_area_num=2)
    plotter.add_image(org_img, title='input')
    plotter.add_image(seg_img_PIL, title='mask (load with PIL)')
    plotter.show_plot()
# Out:
# #  benign1.png
# #  benign10.png
# #  benign100.png
# #  benign101.png
# #  benign102.png

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
        print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.float32(np.array(Image.open(seg_file)))
    seg_img_cv2 = cv2.imread(seg_file)

    plotter = ImageLinePlotter(seg_file, plot_area_num=3)
    plotter.add_image(org_img, title='input')
    plotter.add_image(seg_img_PIL, title='mask (load with PIL)')
    plotter.add_image(seg_img_cv2, title='mask (load with cv2)')
    plotter.show_plot()
# Out:
# #  benign1.png
# #  benign10.png
# #  benign100.png
# #  benign101.png
# #  benign102.png

# %%
ORG_DIR = os.path.join('.', 'VOC2012', 'JPEGImages')
SEG_DIR = os.path.join('.', 'VOC2012', 'SegmentationClass')

segs = glob.glob(os.path.join(SEG_DIR, '*.png'))
segs.sort()

for seg_file in segs[:5]:
    print('# ', os.path.basename(seg_file))
    fname, _ = os.path.splitext(os.path.basename(seg_file))
    org_file = os.path.join(ORG_DIR, fname + '.jpg')
    if not os.path.exists(org_file):
        print('not found org_file : ', org_file)
    org_img = cv2.imread(org_file)
    seg_img_PIL = np.array(Image.open(seg_file))
    seg_img_cv2 = cv2.imread(seg_file)

    print('seg_img_PIL values : ', np.unique(seg_img_PIL))
    print('seg_img_cv2 values : ', np.unique(seg_img_cv2))
# Out:
# #  malignant1.png
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  malignant10.png
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  malignant100.png
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  malignant101.png
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]
# #  malignant102.png
# seg_img_PIL values :  [False  True]
# seg_img_cv2 values :  [  0 255]

# %%
import shutil

TARGET_DIR = os.path.join('.', 'target_data')

ID_CANCER = 1

cls_counters = {}
for seg_file in segs:
    seg_img_PIL = np.array(Image.open(seg_file))

    copy_to = ''
    if np.any(seg_img_PIL == ID_CANCER):
         copy_to += 'cancer_'

    if copy_to == '':
        continue
    if not copy_to in cls_counters.keys():
            cls_counters[copy_to] = 0
    cls_counters[copy_to] += 1

    copy_path = os.path.join(TARGET_DIR, copy_to)
    if not os.path.exists(copy_path):
        os.makedirs(copy_path)
    shutil.copy(seg_file, copy_path)

print(cls_counters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-857c76878a92> in <module>
#       6
#       7 cls_counters = {}
# ----> 8 for seg_file in segs:
#       9     seg_img_PIL = np.array(Image.open(seg_file))
#      10
#
# NameError: name 'segs' is not defined

# %%
chk_data = os.path.join('data', 'train', 'inputs','cancer_', 'malignant1.jpg')

img = Image.open(chk_data)

img_arr = np.array(img)
print('original unique : ', np.unique(img_arr))
print('---------------------------------------------------')

pil_resize = img.resize((1000, 1000))
pil_resize_arr = np.array(pil_resize)
print('PIL resized unique : ', np.unique(pil_resize_arr))
print('---------------------------------------------------')

cv2_resize = cv2.resize(img_arr, (1000, 1000))
print('cv2 resized unique : ', np.unique(cv2_resize))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-684bb3d2b61e> in <module>
#       1 chk_data = os.path.join('data', 'train', 'inputs','cancer_', 'malignant1.jpg')
#       2
# ----> 3 img = Image.open(chk_data)
#       4
#       5 img_arr = np.array(img)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train/inputs/cancer_/malignant1.jpg'

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-01-04 18:08:02.427520: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-01-04 18:08:02.438458: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdb4a757110 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-04 18:08:02.438510: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# <keras.engine.training.Model object at 0x16012d630>
# (Dimension(128), Dimension(128))
# <train> Log :  data/train
# <train> Log :  data/train/teachers
# <train> Log :  train_generator.data_size() :  0
# <train> Log :  valid_generator.data_size() :  0
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Traceback (most recent call last):
#   File "train.py", line 63, in <module>
#     callbacks=[tensorboard_callback]
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/engine/training.py", line 1732, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/engine/training_generator.py", line 76, in fit_generator
#     raise ValueError('`validation_steps=None` is only valid for a'
# ValueError: `validation_steps=None` is only valid for a generator based on the `keras.utils.Sequence` class. Please specify `validation_steps` or use the `keras.utils.Sequence` class.

# %% [markdown]
# #推論

# %%
# !python train_with_checkpointcallback.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-01-11 01:39:12.046568: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-01-11 01:39:12.057798: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9ca50d1330 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-11 01:39:12.057817: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# <train> Log :  train_generator.data_size() :  269
# <train> Log :  valid_generator.data_size() :  88
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/150
# 5/5 [==============================] - 138s 28s/step - loss: 0.6202 - acc: 0.6599 - val_loss: 0.8137 - val_acc: 0.9290
# WARNING:tensorflow:From /Users/gento/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/150
# 5/5 [==============================] - 133s 27s/step - loss: 0.3104 - acc: 0.9164 - val_loss: 0.6932 - val_acc: 0.9433
# Epoch 3/150
# 5/5 [==============================] - 132s 26s/step - loss: 0.2473 - acc: 0.9437 - val_loss: 0.6932 - val_acc: 0.9360
# Epoch 4/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.2139 - acc: 0.9495 - val_loss: 0.6932 - val_acc: 0.9450
# Epoch 5/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.1994 - acc: 0.9446 - val_loss: 0.9512 - val_acc: 0.9362
#
# Epoch 00005: val_loss improved from inf to 0.95125, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 6/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.1866 - acc: 0.9466 - val_loss: 0.9393 - val_acc: 0.9433
# Epoch 7/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.1723 - acc: 0.9478 - val_loss: 0.7370 - val_acc: 0.9406
# Epoch 8/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1678 - acc: 0.9425 - val_loss: 0.8967 - val_acc: 0.9404
# Epoch 9/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1699 - acc: 0.9469 - val_loss: 1.0148 - val_acc: 0.9358
# Epoch 10/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1504 - acc: 0.9466 - val_loss: 0.9315 - val_acc: 0.9430
#
# Epoch 00010: val_loss improved from 0.95125 to 0.93152, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 11/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1385 - acc: 0.9490 - val_loss: 0.6645 - val_acc: 0.9390
# Epoch 12/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.1395 - acc: 0.9552 - val_loss: 0.6705 - val_acc: 0.9365
# Epoch 13/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1353 - acc: 0.9574 - val_loss: 0.9682 - val_acc: 0.9434
# Epoch 14/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1240 - acc: 0.9599 - val_loss: 0.7928 - val_acc: 0.9391
# Epoch 15/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1306 - acc: 0.9595 - val_loss: 0.4040 - val_acc: 0.9396
#
# Epoch 00015: val_loss improved from 0.93152 to 0.40398, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 16/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1205 - acc: 0.9630 - val_loss: 0.6736 - val_acc: 0.9270
# Epoch 17/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1133 - acc: 0.9642 - val_loss: 0.6293 - val_acc: 0.8473
# Epoch 18/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1049 - acc: 0.9658 - val_loss: 0.7629 - val_acc: 0.7610
# Epoch 19/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.1115 - acc: 0.9640 - val_loss: 0.5519 - val_acc: 0.7199
# Epoch 20/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1092 - acc: 0.9639 - val_loss: 0.7464 - val_acc: 0.6605
#
# Epoch 00020: val_loss did not improve from 0.40398
# Epoch 21/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1058 - acc: 0.9654 - val_loss: 1.3715 - val_acc: 0.5512
# Epoch 22/150
# 5/5 [==============================] - 138s 28s/step - loss: 0.1105 - acc: 0.9659 - val_loss: 0.7060 - val_acc: 0.7141
# Epoch 23/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.1077 - acc: 0.9653 - val_loss: 0.8319 - val_acc: 0.7079
# Epoch 24/150
# 5/5 [==============================] - 138s 28s/step - loss: 0.1074 - acc: 0.9651 - val_loss: 1.1721 - val_acc: 0.6054
# Epoch 25/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.1025 - acc: 0.9667 - val_loss: 1.0289 - val_acc: 0.6701
#
# Epoch 00025: val_loss did not improve from 0.40398
# Epoch 26/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0936 - acc: 0.9685 - val_loss: 0.8462 - val_acc: 0.7200
# Epoch 27/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0913 - acc: 0.9703 - val_loss: 0.4808 - val_acc: 0.8495
# Epoch 28/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0837 - acc: 0.9727 - val_loss: 0.4573 - val_acc: 0.8408
# Epoch 29/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0964 - acc: 0.9679 - val_loss: 0.4389 - val_acc: 0.8539
# Epoch 30/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0860 - acc: 0.9708 - val_loss: 0.5381 - val_acc: 0.8154
#
# Epoch 00030: val_loss did not improve from 0.40398
# Epoch 31/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0822 - acc: 0.9725 - val_loss: 0.6030 - val_acc: 0.8294
# Epoch 32/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0886 - acc: 0.9703 - val_loss: 0.6613 - val_acc: 0.7838
# Epoch 33/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0754 - acc: 0.9744 - val_loss: 1.2327 - val_acc: 0.6591
# Epoch 34/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0812 - acc: 0.9728 - val_loss: 0.7183 - val_acc: 0.7506
# Epoch 35/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0767 - acc: 0.9744 - val_loss: 1.2255 - val_acc: 0.6262
#
# Epoch 00035: val_loss did not improve from 0.40398
# Epoch 36/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0792 - acc: 0.9725 - val_loss: 1.1101 - val_acc: 0.6525
# Epoch 37/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0772 - acc: 0.9729 - val_loss: 1.2061 - val_acc: 0.6149
# Epoch 38/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0740 - acc: 0.9747 - val_loss: 1.3369 - val_acc: 0.6558
# Epoch 39/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0707 - acc: 0.9758 - val_loss: 0.9631 - val_acc: 0.6948
# Epoch 40/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0684 - acc: 0.9764 - val_loss: 1.0025 - val_acc: 0.6752
#
# Epoch 00040: val_loss did not improve from 0.40398
# Epoch 41/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0697 - acc: 0.9754 - val_loss: 0.2135 - val_acc: 0.9314
# Epoch 42/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0653 - acc: 0.9772 - val_loss: 0.3973 - val_acc: 0.8164
# Epoch 43/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0628 - acc: 0.9777 - val_loss: 0.2935 - val_acc: 0.9421
# Epoch 44/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0653 - acc: 0.9772 - val_loss: 0.2117 - val_acc: 0.9459
# Epoch 45/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0606 - acc: 0.9789 - val_loss: 0.2773 - val_acc: 0.9002
#
# Epoch 00045: val_loss improved from 0.40398 to 0.27734, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 46/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0574 - acc: 0.9798 - val_loss: 0.2296 - val_acc: 0.9416
# Epoch 47/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0723 - acc: 0.9768 - val_loss: 0.2516 - val_acc: 0.9283
# Epoch 48/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0624 - acc: 0.9779 - val_loss: 0.2616 - val_acc: 0.9409
# Epoch 49/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0615 - acc: 0.9781 - val_loss: 0.2221 - val_acc: 0.9463
# Epoch 50/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0613 - acc: 0.9781 - val_loss: 0.2410 - val_acc: 0.9113
#
# Epoch 00050: val_loss improved from 0.27734 to 0.24104, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 51/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0629 - acc: 0.9781 - val_loss: 0.2325 - val_acc: 0.9231
# Epoch 52/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0554 - acc: 0.9809 - val_loss: 0.3122 - val_acc: 0.8762
# Epoch 53/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0569 - acc: 0.9802 - val_loss: 0.4442 - val_acc: 0.8188
# Epoch 54/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0518 - acc: 0.9825 - val_loss: 0.2783 - val_acc: 0.8969
# Epoch 55/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0562 - acc: 0.9808 - val_loss: 0.2712 - val_acc: 0.8941
#
# Epoch 00055: val_loss did not improve from 0.24104
# Epoch 56/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0538 - acc: 0.9814 - val_loss: 0.2633 - val_acc: 0.9451
# Epoch 57/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0517 - acc: 0.9812 - val_loss: 0.3961 - val_acc: 0.9361
# Epoch 58/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0496 - acc: 0.9829 - val_loss: 0.5138 - val_acc: 0.9368
# Epoch 59/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0510 - acc: 0.9819 - val_loss: 0.3403 - val_acc: 0.9474
# Epoch 60/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0461 - acc: 0.9838 - val_loss: 0.3716 - val_acc: 0.9385
#
# Epoch 00060: val_loss did not improve from 0.24104
# Epoch 61/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0403 - acc: 0.9859 - val_loss: 0.4022 - val_acc: 0.9385
# Epoch 62/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0487 - acc: 0.9829 - val_loss: 0.3812 - val_acc: 0.9409
# Epoch 63/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0430 - acc: 0.9844 - val_loss: 0.3975 - val_acc: 0.9411
# Epoch 64/150
# 5/5 [==============================] - 138s 28s/step - loss: 0.0434 - acc: 0.9849 - val_loss: 0.3765 - val_acc: 0.9379
# Epoch 65/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0443 - acc: 0.9839 - val_loss: 0.4209 - val_acc: 0.9402
#
# Epoch 00065: val_loss did not improve from 0.24104
# Epoch 66/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0445 - acc: 0.9842 - val_loss: 0.4172 - val_acc: 0.9426
# Epoch 67/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0481 - acc: 0.9824 - val_loss: 0.3928 - val_acc: 0.9426
# Epoch 68/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0441 - acc: 0.9845 - val_loss: 0.3534 - val_acc: 0.9416
# Epoch 69/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0431 - acc: 0.9843 - val_loss: 0.3938 - val_acc: 0.9442
# Epoch 70/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0473 - acc: 0.9845 - val_loss: 0.2855 - val_acc: 0.9457
#
# Epoch 00070: val_loss did not improve from 0.24104
# Epoch 71/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0419 - acc: 0.9845 - val_loss: 0.2753 - val_acc: 0.9458
# Epoch 72/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0474 - acc: 0.9825 - val_loss: 0.4004 - val_acc: 0.9421
# Epoch 73/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0374 - acc: 0.9863 - val_loss: 0.2660 - val_acc: 0.9480
# Epoch 74/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0367 - acc: 0.9865 - val_loss: 0.3569 - val_acc: 0.9422
# Epoch 75/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0356 - acc: 0.9867 - val_loss: 0.3280 - val_acc: 0.9450
#
# Epoch 00075: val_loss did not improve from 0.24104
# Epoch 76/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0371 - acc: 0.9863 - val_loss: 0.2611 - val_acc: 0.9555
# Epoch 77/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0305 - acc: 0.9891 - val_loss: 0.2271 - val_acc: 0.9494
# Epoch 78/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0277 - acc: 0.9897 - val_loss: 0.3727 - val_acc: 0.9443
# Epoch 79/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0313 - acc: 0.9887 - val_loss: 0.3028 - val_acc: 0.9530
# Epoch 80/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0274 - acc: 0.9905 - val_loss: 0.3495 - val_acc: 0.9414
#
# Epoch 00080: val_loss did not improve from 0.24104
# Epoch 81/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0226 - acc: 0.9918 - val_loss: 0.2865 - val_acc: 0.9506
# Epoch 82/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0279 - acc: 0.9901 - val_loss: 0.2446 - val_acc: 0.9483
# Epoch 83/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0242 - acc: 0.9912 - val_loss: 0.1855 - val_acc: 0.9555
# Epoch 84/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0343 - acc: 0.9877 - val_loss: 3.1215 - val_acc: 0.4832
# Epoch 85/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0528 - acc: 0.9816 - val_loss: 3.1460 - val_acc: 0.3430
#
# Epoch 00085: val_loss did not improve from 0.24104
# Epoch 86/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0428 - acc: 0.9846 - val_loss: 2.5033 - val_acc: 0.4004
# Epoch 87/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0459 - acc: 0.9840 - val_loss: 1.9680 - val_acc: 0.4769
# Epoch 88/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0373 - acc: 0.9862 - val_loss: 0.8652 - val_acc: 0.7633
# Epoch 89/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0341 - acc: 0.9874 - val_loss: 0.2899 - val_acc: 0.8884
# Epoch 90/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0357 - acc: 0.9873 - val_loss: 0.1762 - val_acc: 0.9622
#
# Epoch 00090: val_loss improved from 0.24104 to 0.17624, saving model to results/unet_100epoch_lr0.01_best.h5
# Epoch 91/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0303 - acc: 0.9888 - val_loss: 0.1412 - val_acc: 0.9617
# Epoch 92/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0252 - acc: 0.9907 - val_loss: 0.1697 - val_acc: 0.9561
# Epoch 93/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0260 - acc: 0.9905 - val_loss: 0.1493 - val_acc: 0.9679
# Epoch 94/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0245 - acc: 0.9909 - val_loss: 0.1624 - val_acc: 0.9633
# Epoch 95/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0275 - acc: 0.9899 - val_loss: 0.2157 - val_acc: 0.9469
#
# Epoch 00095: val_loss did not improve from 0.17624
# Epoch 96/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0207 - acc: 0.9924 - val_loss: 0.2756 - val_acc: 0.9495
# Epoch 97/150
# 5/5 [==============================] - 137s 27s/step - loss: 0.0242 - acc: 0.9913 - val_loss: 0.2308 - val_acc: 0.9544
# Epoch 98/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0234 - acc: 0.9915 - val_loss: 0.2950 - val_acc: 0.9379
# Epoch 99/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0191 - acc: 0.9931 - val_loss: 0.2003 - val_acc: 0.9589
# Epoch 100/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0217 - acc: 0.9922 - val_loss: 0.4003 - val_acc: 0.9433
#
# Epoch 00100: val_loss did not improve from 0.17624
# Epoch 101/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0211 - acc: 0.9924 - val_loss: 0.3108 - val_acc: 0.9549
# Epoch 102/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0226 - acc: 0.9914 - val_loss: 0.1819 - val_acc: 0.9530
# Epoch 103/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0203 - acc: 0.9924 - val_loss: 0.2249 - val_acc: 0.9480
# Epoch 104/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0186 - acc: 0.9931 - val_loss: 0.3700 - val_acc: 0.9394
# Epoch 105/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0171 - acc: 0.9937 - val_loss: 0.2490 - val_acc: 0.9585
#
# Epoch 00105: val_loss did not improve from 0.17624
# Epoch 106/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0151 - acc: 0.9943 - val_loss: 0.4278 - val_acc: 0.9472
# Epoch 107/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0169 - acc: 0.9938 - val_loss: 0.2898 - val_acc: 0.9569
# Epoch 108/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0174 - acc: 0.9934 - val_loss: 0.2416 - val_acc: 0.9490
# Epoch 109/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0243 - acc: 0.9912 - val_loss: 0.2040 - val_acc: 0.9615
# Epoch 110/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0401 - acc: 0.9877 - val_loss: 0.3133 - val_acc: 0.9409
#
# Epoch 00110: val_loss did not improve from 0.17624
# Epoch 111/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0356 - acc: 0.9876 - val_loss: 0.3646 - val_acc: 0.8977
# Epoch 112/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0348 - acc: 0.9874 - val_loss: 0.1776 - val_acc: 0.9544
# Epoch 113/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0374 - acc: 0.9861 - val_loss: 0.1649 - val_acc: 0.9484
# Epoch 114/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0280 - acc: 0.9893 - val_loss: 0.1713 - val_acc: 0.9451
# Epoch 115/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0303 - acc: 0.9894 - val_loss: 0.2374 - val_acc: 0.9426
#
# Epoch 00115: val_loss did not improve from 0.17624
# Epoch 116/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0230 - acc: 0.9916 - val_loss: 0.2157 - val_acc: 0.9653
# Epoch 117/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0191 - acc: 0.9931 - val_loss: 0.2668 - val_acc: 0.9623
# Epoch 118/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0168 - acc: 0.9940 - val_loss: 0.2048 - val_acc: 0.9635
# Epoch 119/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0172 - acc: 0.9936 - val_loss: 0.2784 - val_acc: 0.9557
# Epoch 120/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.1922 - val_acc: 0.9650
#
# Epoch 00120: val_loss did not improve from 0.17624
# Epoch 121/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0147 - acc: 0.9945 - val_loss: 0.3333 - val_acc: 0.9550
# Epoch 122/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0129 - acc: 0.9952 - val_loss: 0.3643 - val_acc: 0.9571
# Epoch 123/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0117 - acc: 0.9957 - val_loss: 0.3804 - val_acc: 0.9558
# Epoch 124/150
# 5/5 [==============================] - 141s 28s/step - loss: 0.0122 - acc: 0.9954 - val_loss: 0.3048 - val_acc: 0.9530
# Epoch 125/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0125 - acc: 0.9955 - val_loss: 0.2560 - val_acc: 0.9603
#
# Epoch 00125: val_loss did not improve from 0.17624
# Epoch 126/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0103 - acc: 0.9961 - val_loss: 0.2909 - val_acc: 0.9567
# Epoch 127/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0105 - acc: 0.9959 - val_loss: 0.2698 - val_acc: 0.9570
# Epoch 128/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0094 - acc: 0.9963 - val_loss: 0.3429 - val_acc: 0.9537
# Epoch 129/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0106 - acc: 0.9959 - val_loss: 0.2749 - val_acc: 0.9593
# Epoch 130/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0098 - acc: 0.9962 - val_loss: 0.3515 - val_acc: 0.9583
#
# Epoch 00130: val_loss did not improve from 0.17624
# Epoch 131/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0100 - acc: 0.9960 - val_loss: 0.2841 - val_acc: 0.9608
# Epoch 132/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0107 - acc: 0.9959 - val_loss: 0.2722 - val_acc: 0.9632
# Epoch 133/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0097 - acc: 0.9962 - val_loss: 0.3707 - val_acc: 0.9564
# Epoch 134/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0106 - acc: 0.9959 - val_loss: 0.2636 - val_acc: 0.9661
# Epoch 135/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0095 - acc: 0.9963 - val_loss: 0.2225 - val_acc: 0.9676
#
# Epoch 00135: val_loss did not improve from 0.17624
# Epoch 136/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0093 - acc: 0.9963 - val_loss: 0.2745 - val_acc: 0.9599
# Epoch 137/150
# 5/5 [==============================] - 135s 27s/step - loss: 0.0088 - acc: 0.9964 - val_loss: 0.1812 - val_acc: 0.9623
# Epoch 138/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0082 - acc: 0.9967 - val_loss: 0.2469 - val_acc: 0.9640
# Epoch 139/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0080 - acc: 0.9968 - val_loss: 0.2017 - val_acc: 0.9595
# Epoch 140/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0090 - acc: 0.9963 - val_loss: 0.2777 - val_acc: 0.9637
#
# Epoch 00140: val_loss did not improve from 0.17624
# Epoch 141/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0091 - acc: 0.9964 - val_loss: 0.2545 - val_acc: 0.9626
# Epoch 142/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0088 - acc: 0.9964 - val_loss: 0.3064 - val_acc: 0.9577
# Epoch 143/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0079 - acc: 0.9968 - val_loss: 0.2731 - val_acc: 0.9572
# Epoch 144/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0078 - acc: 0.9968 - val_loss: 0.2606 - val_acc: 0.9597
# Epoch 145/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0072 - acc: 0.9971 - val_loss: 0.2881 - val_acc: 0.9612
#
# Epoch 00145: val_loss did not improve from 0.17624
# Epoch 146/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0068 - acc: 0.9972 - val_loss: 0.3020 - val_acc: 0.9645
# Epoch 147/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0067 - acc: 0.9973 - val_loss: 0.2096 - val_acc: 0.9606
# Epoch 148/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0067 - acc: 0.9972 - val_loss: 0.3162 - val_acc: 0.9567
# Epoch 149/150
# 5/5 [==============================] - 134s 27s/step - loss: 0.0068 - acc: 0.9972 - val_loss: 0.3243 - val_acc: 0.9594
# Epoch 150/150
# 5/5 [==============================] - 136s 27s/step - loss: 0.0066 - acc: 0.9973 - val_loss: 0.2483 - val_acc: 0.9652
#
# Epoch 00150: val_loss did not improve from 0.17624

# %%
RESULT_NAME_1 = 'results'

RESULT_TYPE_MASK = 'predict_outputs'
RESULT_TYPE_ARGMAX = 'argmax_outputs'
RESULT_TYPE_OVERLAY = 'overlay_outputs'

DATATYPE_TRAIN = 'train'
DATATYPE_VALID = 'valid'

def DATATYPE_PREDICTS(data_type):
    return data_type + '_predicts'

def DATATYPE_TEACHERS(data_type):
    return data_type + '_teachers'

IDX_CLASS_CANCER = 0
IDXES = [IDX_CLASS_CANCER]

def RESULTS_DIR(result_name, data_type, result_type):
    return os.path.join(result_name, data_type, result_type)


def eval_iou(result_name, data_type):
    pred_mask_dir = RESULTS_DIR(result_name, DATATYPE_PREDICTS(data_type), RESULT_TYPE_MASK)
    teacher_mask_dir = RESULTS_DIR(result_name, DATATYPE_TEACHERS(data_type), RESULT_TYPE_MASK)
    if not os.path.exists(teacher_mask_dir):
        print('teachers dir is not found. : ', teacher_mask_dir)
        return False

    print('target pred dir : ', pred_mask_dir)

    pred_mask_files = glob.glob(os.path.join(pred_mask_dir, '*.png'))
    pred_mask_files.sort()

    all_ious = {}
    for target_idx in IDXES:
        all_ious[target_idx] = []

    if len(pred_mask_files) < 1:
        print('pred_mask_files is []')

    for p_mask_file in pred_mask_files:
        fname = os.path.basename(p_mask_file)
        t_mask_file = os.path.join(teacher_mask_dir, fname)
        if not os.path.exists(t_mask_file):
            print('teacher mask is not found.')
            continue

        p_masks = cv2.imread(p_mask_file)
        t_masks = cv2.imread(t_mask_file)

        iou_print = ','
        for target_idx in IDXES:
            p_mask = p_masks[:, :, target_idx]
            t_mask = t_masks[:, :, target_idx]
            iou = calculate_iou(p_mask, t_mask)
            iou_print += '%.3f, ' % iou
            if np.isnan(iou):
                continue
            all_ious[target_idx].append(iou)

        print(fname, iou_print)

    mean_iou_print = 'mean:'
    for target_idx in IDXES:
        mean_iou = np.average(np.array(all_ious[target_idx]))
        mean_iou_print += '%.3f, ' % mean_iou
    print('')
    print(mean_iou_print)


def calculate_iou(p_mask, t_mask):
    p_mask = to_binary(p_mask)
    t_mask = to_binary(t_mask)

    if np.sum(t_mask) == 0:
        return np.nan

    overlap = np.sum(p_mask * t_mask)
    union = np.sum(to_binary(p_mask + t_mask))

    return overlap / union


def to_binary(mask, val=1):
    mask[mask > 0] = val
    return mask

# %%
eval_iou(RESULT_NAME_1, DATATYPE_VALID)
# Out:
# target pred dir :  results/train_predicts/predict_outputs
# benign1.png ,0.427,
# benign10.png ,0.946,
# benign101.png ,0.676,
# benign104.png ,0.851,
# benign105.png ,0.843,
# benign107.png ,0.491,
# benign11.png ,0.829,
# benign110.png ,0.601,
# benign111.png ,0.733,
# benign112.png ,0.775,
# benign113.png ,0.775,
# benign115.png ,0.831,
# benign118.png ,0.000,
# benign12.png ,0.036,
# benign120.png ,0.000,
# benign123.png ,0.725,
# benign124.png ,0.000,
# benign126.png ,0.557,
# benign128.png ,0.224,
# benign129.png ,0.785,
# benign130.png ,0.946,
# benign132.png ,0.869,
# benign134.png ,0.000,
# benign135.png ,0.517,
# benign138.png ,0.505,
# benign139.png ,0.791,
# benign14.png ,0.611,
# benign140.png ,0.494,
# benign143.png ,0.611,
# benign144.png ,0.000,
# benign145.png ,0.641,
# benign146.png ,0.014,
# benign148.png ,0.796,
# benign149.png ,0.456,
# benign15.png ,0.515,
# benign150.png ,0.000,
# benign151.png ,0.863,
# benign153.png ,0.464,
# benign154.png ,0.000,
# benign155.png ,0.835,
# benign157.png ,0.814,
# benign158.png ,0.892,
# benign160.png ,0.593,
# benign161.png ,0.606,
# benign162.png ,0.000,
# benign163.png ,0.113,
# benign166.png ,0.340,
# benign167.png ,0.588,
# benign168.png ,0.905,
# benign169.png ,0.000,
# benign170.png ,0.571,
# benign171.png ,0.000,
# benign172.png ,0.662,
# benign174.png ,0.838,
# benign175.png ,0.846,
# benign176.png ,0.738,
# benign178.png ,0.821,
# benign179.png ,0.000,
# benign18.png ,0.872,
# benign180.png ,0.757,
# benign181.png ,0.663,
# benign182.png ,0.052,
# benign183.png ,0.000,
# benign184.png ,0.830,
# benign186.png ,0.826,
# benign187.png ,0.640,
# benign189.png ,0.514,
# benign19.png ,0.000,
# benign190.png ,0.684,
# benign192.png ,0.850,
# benign194.png ,0.000,
# benign197.png ,0.000,
# benign198.png ,0.812,
# benign2.png ,0.766,
# benign20.png ,0.590,
# benign200.png ,0.411,
# benign202.png ,0.000,
# benign203.png ,0.000,
# benign206.png ,0.038,
# benign208.png ,0.754,
# benign209.png ,0.576,
# benign21.png ,0.237,
# benign213.png ,0.617,
# benign214.png ,0.671,
# benign215.png ,0.398,
# benign217.png ,0.654,
# benign218.png ,0.378,
# benign219.png ,0.000,
# benign22.png ,0.809,
# benign220.png ,0.000,
# benign222.png ,0.235,
# benign226.png ,0.559,
# benign227.png ,0.356,
# benign229.png ,0.828,
# benign23.png ,0.842,
# benign230.png ,0.356,
# benign231.png ,0.787,
# benign234.png ,0.072,
# benign237.png ,0.437,
# benign238.png ,0.741,
# benign24.png ,0.577,
# benign240.png ,0.045,
# benign241.png ,0.799,
# benign244.png ,0.478,
# benign245.png ,0.584,
# benign249.png ,0.000,
# benign25.png ,0.510,
# benign250.png ,0.322,
# benign252.png ,0.219,
# benign254.png ,0.000,
# benign255.png ,0.045,
# benign258.png ,0.586,
# benign259.png ,0.785,
# benign26.png ,0.920,
# benign261.png ,0.153,
# benign263.png ,0.241,
# benign264.png ,0.199,
# benign266.png ,0.382,
# benign268.png ,0.668,
# benign27.png ,0.806,
# benign270.png ,0.190,
# benign271.png ,0.254,
# benign274.png ,0.430,
# benign275.png ,0.703,
# benign276.png ,0.448,
# benign277.png ,0.053,
# benign278.png ,0.676,
# benign279.png ,0.788,
# benign28.png ,0.662,
# benign280.png ,0.884,
# benign281.png ,0.744,
# benign282.png ,0.000,
# benign284.png ,0.521,
# benign285.png ,0.628,
# benign287.png ,0.374,
# benign289.png ,0.000,
# benign29.png ,0.000,
# benign291.png ,0.815,
# benign295.png ,0.618,
# benign297.png ,0.688,
# benign3.png ,0.661,
# benign30.png ,0.315,
# benign301.png ,0.000,
# benign303.png ,0.001,
# benign305.png ,0.599,
# benign308.png ,0.070,
# benign31.png ,0.708,
# benign310.png ,0.000,
# benign312.png ,0.280,
# benign315.png ,0.031,
# benign316.png ,0.000,
# benign317.png ,0.000,
# benign319.png ,0.775,
# benign320.png ,0.728,
# benign321.png ,0.403,
# benign323.png ,0.681,
# benign324.png ,0.630,
# benign326.png ,0.920,
# benign327.png ,0.952,
# benign328.png ,0.915,
# benign33.png ,0.947,
# benign330.png ,0.899,
# benign331.png ,0.556,
# benign332.png ,0.579,
# benign337.png ,0.328,
# benign338.png ,0.000,
# benign339.png ,0.653,
# benign34.png ,0.906,
# benign340.png ,0.374,
# benign342.png ,0.000,
# benign343.png ,0.000,
# benign347.png ,0.000,
# benign348.png ,0.146,
# benign349.png ,0.000,
# benign35.png ,0.487,
# benign351.png ,0.007,
# benign353.png ,0.000,
# benign354.png ,0.104,
# benign356.png ,0.191,
# benign357.png ,0.000,
# benign358.png ,0.520,
# benign359.png ,0.000,
# benign36.png ,0.682,
# benign361.png ,0.002,
# benign362.png ,0.000,
# benign364.png ,0.000,
# benign368.png ,0.009,
# benign369.png ,0.752,
# benign37.png ,0.112,
# benign370.png ,0.376,
# benign372.png ,0.201,
# benign373.png ,0.705,
# benign375.png ,0.000,
# benign376.png ,0.154,
# benign378.png ,0.000,
# benign380.png ,0.179,
# benign381.png ,0.015,
# benign382.png ,0.207,
# benign384.png ,0.000,
# benign386.png ,0.259,
# benign387.png ,0.763,
# benign388.png ,0.000,
# benign389.png ,0.047,
# benign39.png ,0.655,
# benign390.png ,0.100,
# benign393.png ,0.212,
# benign399.png ,0.000,
# benign40.png ,0.616,
# benign403.png ,0.000,
# benign406.png ,0.000,
# benign41.png ,0.509,
# benign411.png ,0.002,
# benign412.png ,0.038,
# benign418.png ,0.000,
# benign419.png ,0.870,
# benign423.png ,0.000,
# benign425.png ,0.756,
# benign426.png ,0.022,
# benign428.png ,0.177,
# benign429.png ,0.349,
# benign431.png ,0.000,
# benign432.png ,0.923,
# benign434.png ,0.672,
# benign437.png ,0.000,
# benign45.png ,0.777,
# benign47.png ,0.778,
# benign48.png ,0.786,
# benign49.png ,0.772,
# benign50.png ,0.709,
# benign52.png ,0.000,
# benign53.png ,0.237,
# benign54.png ,0.906,
# benign55.png ,0.156,
# benign56.png ,0.355,
# benign57.png ,0.232,
# benign58.png ,0.513,
# benign59.png ,0.708,
# benign6.png ,0.786,
# benign60.png ,0.447,
# benign62.png ,0.546,
# benign63.png ,0.000,
# benign64.png ,0.006,
# benign65.png ,0.711,
# benign66.png ,0.925,
# benign67.png ,0.518,
# benign69.png ,0.000,
# benign7.png ,0.468,
# benign70.png ,0.000,
# benign71.png ,0.000,
# benign73.png ,0.535,
# benign75.png ,0.481,
# benign76.png ,0.500,
# benign77.png ,0.377,
# benign79.png ,0.343,
# benign81.png ,0.000,
# benign82.png ,0.759,
# benign83.png ,0.262,
# benign84.png ,0.759,
# benign86.png ,0.095,
# benign87.png ,0.758,
# benign89.png ,0.687,
# benign9.png ,0.940,
# benign90.png ,0.144,
# benign91.png ,0.000,
# benign92.png ,0.863,
# benign93.png ,0.365,
# benign95.png ,0.729,
# benign96.png ,0.638,
# benign97.png ,0.276,
#
# mean:0.425,

# %%
from enum import Enum

EVAL_EXCESS_DIR = 'eval_excess'
EVAL_DEFICIENCY_DIR = 'eval_deficiency'
EVAL_EXCESS_AND_DEFICIENCY_DIR = 'eval_excess_and_deficiency'

CLASS_NAME_CANCER = 'CANCER'
CLASS_NAMES = [CLASS_NAME_CANCER]


class OutputType(Enum):
    TEXT = 0
    IMAGE = 1
    BOTH = 2


def prepare_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    return dir_path


def eval_excesses_and_deficiencies(result_name, data_type,output_type=OutputType.TEXT, with_save=False):
    pred_mask_dir = RESULTS_DIR(result_name, DATATYPE_PREDICTS(data_type), RESULT_TYPE_MASK)
    teacher_mask_dir = RESULTS_DIR(result_name, DATATYPE_TEACHERS(data_type), RESULT_TYPE_MASK)

    print('target pred dir : ', pred_mask_dir)

    pred_mask_files = glob.glob(os.path.join(pred_mask_dir, '*.png'))
    pred_mask_files.sort()

    all_excesses = {}
    all_deficiencies = {}
    all_deficiencies_to_teacher = {}
    count_teachers = {}

    for target_idx in IDXES:
        all_excesses[target_idx] = []
        all_deficiencies[target_idx] = []
        all_deficiencies_to_teacher[target_idx] = []
        count_teachers[target_idx] = 0


    if len(pred_mask_files) < 1:
        print('pred_mask_files is []')

    for k, p_mask_file in enumerate(pred_mask_files):
        fname = os.path.basename(p_mask_file)
        t_mask_file = os.path.join(teacher_mask_dir, fname)
        if not os.path.exists(t_mask_file):
            print('teacher mask is not found.')
            continue

        p_masks = cv2.imread(p_mask_file)
        t_masks = cv2.imread(t_mask_file)

#         save_base_dir = RESULTS_DIR(result_name, model_type, data_type, '')
        save_base_dir = "results"
        eval_excess_and_deficiency(fname, p_masks, t_masks, all_excesses, all_deficiencies,
                    all_deficiencies_to_teacher, count_teachers,
                    output_type=output_type, with_save=with_save, save_base_dir=save_base_dir)

    if output_type == OutputType.TEXT or output_type == OutputType.BOTH:
        mean_excesses_print = ':'
        mean_deficiencies_print = ':'
        mean_deficiencies_to_teacher_print = ':'
        excesses_rate_print = ':'
        deficiencies_rate_print = ':'
        deficiencies_to_teacher_rate_print = ':'
        for target_idx in IDXES:
            mean_excesses = np.average(np.array(all_excesses[target_idx]))
            mean_deficiencies = np.average(np.array(all_deficiencies[target_idx]))
            mean_deficiencies_to_teacher = np.average(np.array(all_deficiencies_to_teacher[target_idx]))
            mean_excesses_print += '%.3f, ' % mean_excesses
            mean_deficiencies_print += '%.3f, ' % mean_deficiencies
            mean_deficiencies_to_teacher_print += '%.3f, ' % mean_deficiencies_to_teacher
            excesses_rate_print += '%.3f, ' % (len(all_excesses[target_idx]) / len(pred_mask_files))
            deficiencies_rate_print += '%.3f, ' % (len(all_deficiencies[target_idx]) / len(pred_mask_files))
            deficiencies_to_teacher_rate = 0
            if count_teachers[target_idx] != 0:
                deficiencies_to_teacher_rate = len(all_deficiencies[target_idx]) / count_teachers[target_idx]
            deficiencies_to_teacher_rate_print += '%.3f, ' % deficiencies_to_teacher_rate
        print('')
        print('rate:', excesses_rate_print, deficiencies_rate_print)
        print('mean:', mean_excesses_print, mean_deficiencies_print, mean_deficiencies_to_teacher_print)


def eval_excess_and_deficiency(fname, p_masks, t_masks, all_excesses, all_deficiencies,
                            all_deficiencies_to_teacher, count_teachers,
                            output_type=OutputType.TEXT, with_save=False, save_base_dir=''):
    img_h, img_w = np.shape(p_masks)[:2]
    img_size = img_h * img_w

    excesses_print = ','
    deficiencies_print = ','
    deficiencies_to_teacher_print = ','
    image_plotter = ImageLinePlotter(plot_area_num=len(IDXES))
    for target_idx, cname in zip(IDXES, CLASS_NAMES):
        p_mask = to_binary(p_masks[:, :, target_idx])
        t_mask = to_binary(t_masks[:, :, target_idx])
        e_mask, d_mask, o_mask = make_excess_and_deficiency(p_mask, t_mask)
        excesses = np.sum(e_mask) / img_size
        deficiencies = np.sum(d_mask) / img_size
        if np.sum(t_mask) != 0:
            count_teachers[target_idx] += 1
            deficiencies_to_teacher = np.sum(d_mask) / np.sum(t_mask)
        else:
            deficiencies_to_teacher = 0
        excesses_print += '%.3f, ' % excesses
        deficiencies_print += '%.3f, ' % deficiencies
        deficiencies_to_teacher_print += '%.3f, ' % deficiencies_to_teacher
        if excesses != 0:
            all_excesses[target_idx].append(excesses)
        if deficiencies != 0:
            all_deficiencies[target_idx].append(deficiencies)
        if deficiencies_to_teacher != 0:
            all_deficiencies_to_teacher[target_idx].append(deficiencies_to_teacher)
        dummy_mask = np.zeros(np.shape(p_mask)[:2], dtype=np.uint8)
        eval_img = np.stack([d_mask * 255, o_mask * 120, e_mask * 255], axis=2)
        eval_img = eval_img.astype(np.uint8)
        image_plotter.add_image(eval_img, title=cname)
        if with_save:
            e_img = np.stack([dummy_mask, dummy_mask, e_mask * 255], axis=2)
            d_img = np.stack([d_mask * 255, dummy_mask, dummy_mask], axis=2)
            save_excess_dir = prepare_dir(os.path.join(save_base_dir, EVAL_EXCESS_DIR))
            save_deficiency_dir = prepare_dir(os.path.join(save_base_dir, EVAL_DEFICIENCY_DIR))
            save_excess_and_deficiency_dir = prepare_dir(os.path.join(save_base_dir, EVAL_EXCESS_AND_DEFICIENCY_DIR))
            cv2.imwrite(os.path.join(save_excess_dir, fname), e_img)
            cv2.imwrite(os.path.join(save_deficiency_dir, fname), d_img)
            cv2.imwrite(os.path.join(save_excess_and_deficiency_dir, fname), eval_img)

    if output_type == OutputType.TEXT or output_type == OutputType.BOTH:
        print(fname, excesses_print, deficiencies_print, deficiencies_to_teacher_print)
    else:
        print(fname)

    if output_type == OutputType.IMAGE or output_type == OutputType.BOTH:
        image_plotter.show_plot()

    return all_excesses, all_deficiencies, all_deficiencies_to_teacher, count_teachers


def make_excess_and_deficiency(p_mask, t_mask):
    e_mask = (p_mask - t_mask).astype(np.int8)
    e_mask[e_mask < 0] = 0
    e_mask = e_mask.astype(np.uint8)

    d_mask = (t_mask - p_mask).astype(np.int8)
    d_mask[d_mask < 0] = 0
    d_mask = d_mask.astype(np.uint8)

    o_mask = p_mask * t_mask

    return e_mask, d_mask, o_mask

# %%
eval_excesses_and_deficiencies(RESULT_NAME_1, DATATYPE_VALID, output_type=OutputType.TEXT)
# Out:
# target pred dir :  results/valid_predicts/predict_outputs
# benign100.png ,0.001,  ,0.012,  ,0.202,
# benign102.png ,0.000,  ,0.025,  ,0.500,
# benign103.png ,0.001,  ,0.017,  ,0.142,
# benign106.png ,0.000,  ,0.007,  ,0.308,
# benign109.png ,0.006,  ,0.004,  ,0.028,
# benign117.png ,0.000,  ,0.002,  ,0.071,
# benign121.png ,0.000,  ,0.007,  ,0.139,
# benign125.png ,0.001,  ,0.001,  ,0.074,
# benign13.png ,0.001,  ,0.007,  ,0.049,
# benign133.png ,0.000,  ,0.001,  ,0.157,
# benign136.png ,0.004,  ,0.001,  ,0.026,
# benign142.png ,0.000,  ,0.001,  ,0.101,
# benign152.png ,0.001,  ,0.023,  ,0.118,
# benign156.png ,0.000,  ,0.001,  ,0.055,
# benign159.png ,0.001,  ,0.000,  ,0.069,
# benign16.png ,0.000,  ,0.000,  ,0.022,
# benign165.png ,0.007,  ,0.003,  ,0.414,
# benign17.png ,0.003,  ,0.000,  ,0.024,
# benign173.png ,0.007,  ,0.017,  ,0.146,
# benign177.png ,0.005,  ,0.000,  ,0.038,
# benign191.png ,0.001,  ,0.000,  ,0.018,
# benign193.png ,0.000,  ,0.001,  ,0.091,
# benign195.png ,0.001,  ,0.316,  ,0.861,
# benign204.png ,0.000,  ,0.012,  ,0.254,
# benign211.png ,0.001,  ,0.001,  ,0.149,
# benign216.png ,0.001,  ,0.011,  ,0.208,
# benign221.png ,0.000,  ,0.007,  ,1.000,
# benign232.png ,0.000,  ,0.015,  ,0.137,
# benign239.png ,0.000,  ,0.002,  ,0.112,
# benign246.png ,0.001,  ,0.002,  ,0.270,
# benign251.png ,0.000,  ,0.009,  ,0.416,
# benign253.png ,0.001,  ,0.007,  ,0.216,
# benign260.png ,0.002,  ,0.020,  ,0.415,
# benign265.png ,0.001,  ,0.009,  ,0.191,
# benign267.png ,0.000,  ,0.017,  ,0.445,
# benign273.png ,0.000,  ,0.011,  ,0.114,
# benign283.png ,0.000,  ,0.011,  ,1.000,
# benign286.png ,0.000,  ,0.053,  ,0.478,
# benign290.png ,0.004,  ,0.043,  ,0.354,
# benign296.png ,0.000,  ,0.045,  ,0.369,
# benign300.png ,0.001,  ,0.005,  ,0.060,
# benign307.png ,0.000,  ,0.002,  ,0.063,
# benign311.png ,0.000,  ,0.094,  ,1.000,
# benign318.png ,0.000,  ,0.000,  ,0.059,
# benign322.png ,0.000,  ,0.002,  ,0.121,
# benign325.png ,0.001,  ,0.002,  ,0.159,
# benign329.png ,0.001,  ,0.000,  ,0.049,
# benign336.png ,0.000,  ,0.022,  ,1.000,
# benign341.png ,0.001,  ,0.122,  ,0.864,
# benign346.png ,0.002,  ,0.036,  ,0.230,
# benign350.png ,0.001,  ,0.107,  ,0.808,
# benign352.png ,0.000,  ,0.003,  ,0.242,
# benign355.png ,0.000,  ,0.112,  ,0.782,
# benign360.png ,0.000,  ,0.013,  ,0.449,
# benign363.png ,0.000,  ,0.019,  ,1.000,
# benign365.png ,0.000,  ,0.004,  ,0.121,
# benign366.png ,0.002,  ,0.010,  ,0.147,
# benign371.png ,0.006,  ,0.014,  ,0.383,
# benign374.png ,0.000,  ,0.006,  ,1.000,
# benign377.png ,0.000,  ,0.020,  ,1.000,
# benign379.png ,0.025,  ,0.022,  ,0.722,
# benign38.png ,0.001,  ,0.000,  ,0.014,
# benign383.png ,0.000,  ,0.056,  ,0.941,
# benign385.png ,0.001,  ,0.013,  ,0.383,
# benign395.png ,0.001,  ,0.050,  ,0.487,
# benign4.png ,0.000,  ,0.001,  ,0.093,
# benign407.png ,0.000,  ,0.299,  ,0.979,
# benign416.png ,0.000,  ,0.034,  ,1.000,
# benign417.png ,0.000,  ,0.026,  ,1.000,
# benign421.png ,0.002,  ,0.038,  ,0.318,
# benign427.png ,0.017,  ,0.058,  ,0.733,
# benign43.png ,0.000,  ,0.003,  ,0.400,
# benign430.png ,0.003,  ,0.014,  ,0.433,
# benign433.png ,0.000,  ,0.007,  ,0.555,
# benign435.png ,0.000,  ,0.002,  ,0.183,
# benign436.png ,0.007,  ,0.089,  ,0.865,
# benign44.png ,0.001,  ,0.000,  ,0.015,
# benign46.png ,0.000,  ,0.000,  ,0.051,
# benign5.png ,0.000,  ,0.002,  ,0.157,
# benign51.png ,0.000,  ,0.001,  ,0.083,
# benign68.png ,0.002,  ,0.043,  ,0.222,
# benign72.png ,0.002,  ,0.006,  ,0.076,
# benign74.png ,0.000,  ,0.001,  ,0.103,
# benign78.png ,0.001,  ,0.002,  ,0.117,
# benign8.png ,0.000,  ,0.008,  ,0.736,
# benign80.png ,0.024,  ,0.091,  ,0.397,
# benign98.png ,0.023,  ,0.107,  ,0.367,
# benign99.png ,0.002,  ,0.002,  ,0.056,
#
# rate: :0.784,  :1.000,
# mean: :0.003,  :0.026,  :0.350,

# %%
eval_excesses_and_deficiencies(RESULT_NAME_1, DATATYPE_VALID, output_type=OutputType.IMAGE)
# Out:
# target pred dir :  results/valid_predicts/predict_outputs
# benign100.png
# benign102.png
# benign103.png
# benign106.png
# benign109.png
# benign117.png
# benign121.png
# benign125.png
# benign13.png
# benign133.png
# benign136.png
# benign142.png
# benign152.png
# benign156.png
# benign159.png
# benign16.png
# benign165.png
# benign17.png
# benign173.png
# benign177.png
# benign191.png
# benign193.png
# benign195.png
# benign204.png
# benign211.png
# benign216.png
# benign221.png
# benign232.png
# benign239.png
# benign246.png
# benign251.png
# benign253.png
# benign260.png
# benign265.png
# benign267.png
# benign273.png
# benign283.png
# benign286.png
# benign290.png
# benign296.png
# benign300.png
# benign307.png
# benign311.png
# benign318.png
# benign322.png
# benign325.png
# benign329.png
# benign336.png
# benign341.png
# benign346.png
# benign350.png
# benign352.png
# benign355.png
# benign360.png
# benign363.png
# benign365.png
# benign366.png
# benign371.png
# benign374.png
# benign377.png
# benign379.png
# benign38.png
# benign383.png
# benign385.png
# benign395.png
# benign4.png
# benign407.png
# benign416.png
# benign417.png
# benign421.png
# benign427.png
# benign43.png
# benign430.png
# benign433.png
# benign435.png
# benign436.png
# benign44.png
# benign46.png
# benign5.png
# benign51.png
# benign68.png
# benign72.png
# benign74.png
# benign78.png
# benign8.png
# benign80.png
# benign98.png
# benign99.png

# %% [markdown]
# arearatioの計算
